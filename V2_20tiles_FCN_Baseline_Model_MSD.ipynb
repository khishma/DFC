# %% [markdown]
# # 20 tiles

# %% [markdown]
# ## Utils

# %%
# !pip install fiona
# !pip install rasterio
# !pip install tqdm
# Out:
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/37/94/4910fd55246c1d963727b03885ead6ef1cd3748a465f7b0239ab25dfc9a3/Fiona-1.8.18-cp36-cp36m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 301kB/s
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona) (7.1.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona) (1.15.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fiona) (2020.12.5)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona) (20.3.0)
# Installing collected packages: click-plugins, cligj, munch, fiona
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 munch-2.5.0
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/33/1a/51baddc8581ead98fcef591624b4b2521b581943a9178912a2ac576e0235/rasterio-1.1.8-1-cp36-cp36m-manylinux1_x86_64.whl (18.3MB)
#      |████████████████████████████████| 18.3MB 70.7MB/s
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from rasterio) (0.7.1)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from rasterio) (7.1.2)
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.19.5)
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from rasterio) (20.3.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.3.0 rasterio-1.1.8 snuggs-1.4.7
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
import rasterio 
import matplotlib.pyplot as plt
import numpy as np
import fiona
import pandas as pd
import torch
torch.backends.cudnn.benchmark = True
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import datetime
from tqdm import tqdm
from torchvision.transforms import transforms
import os
import sys
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.errors import RasterioError, RasterioIOError
import torch 
from torchvision import transforms
from torch.utils.data.dataset import IterableDataset

# %%
#Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Split data in to train and validation

# %% [markdown]
# Using NLCD as labels, train with both years at the same time

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)
        
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_both.csv", index=False)

# %% [markdown]
# Using NLCD as labels, train with a single year at a time
#
# 2013 NAIP, 2013 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv", index=False)

# %% [markdown]
# 2017 NAIP, 2017 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2017.csv", index=False)

# %%
input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'


input_dataframe = pd.read_csv(input_fn, nrows=21 )
#input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
print(image_fns)
label_fns = input_dataframe["label_fn"].values
print(label_fns)
groups = input_dataframe["group"].values
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif']
# ['https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/546_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/597_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/596_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/595_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/541_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/497_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/496_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/545_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/544_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/543_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/542_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1033_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1032_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1031_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1030_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1083_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1082_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1081_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/979_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/978_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/977_nlcd-2013.tif']

# %% [markdown]
# ## Dataset Loader

# %%
class StreamingGeospatialDataset(IterableDataset):
    
    def __init__(self, imagery_fns, label_fns=None, groups=None, chip_size=32, num_chips_per_tile=200, windowed_sampling=False, image_transform=None, label_transform=None, nodata_check=None, verbose=False):
        """A torch Dataset for randomly sampling chips from a list of tiles. When used in conjunction with a DataLoader that has `num_workers>1` this Dataset will assign each worker to sample chips from disjoint sets of tiles.
        Args:
            imagery_fns: A list of filenames (or URLS -- anything that `rasterio.open()` can read) pointing to imagery tiles.
            label_fns: A list of filenames of the same size as `imagery_fns` pointing to label mask tiles or `None` if the Dataset should operate in "imagery only mode". Note that we expect `imagery_fns[i]` and `label_fns[i]` to have the same dimension and coordinate system.
            groups: Optional: A list of integers of the same size as `imagery_fns` that gives the "group" membership of each tile. This can be used to normalize imagery from different groups differently.
            chip_size: Desired size of chips (in pixels).
            num_chips_per_tile: Desired number of chips to sample for each tile.
            windowed_sampling: Flag indicating whether we should sample each chip with a read using `rasterio.windows.Window` or whether we should read the whole tile into memory, then sample chips.
            image_transform: A function to apply to each image chip object. If this is `None`, then the only transformation applied to the loaded imagery will be to convert it to a `torch.Tensor`. If this is not `None`, then the function should return a `Torch.tensor`. Further, if `groups` is not `None` then the transform function should expect the imagery as the first argument and the group as the second argument.
            label_transform: Similar to image_transform, but applied to label chips.
            nodata_check: A method that will check an `(image_chip)` or `(image_chip, label_chip)` (if `label_fns` are provided) and return whether or not the chip should be skipped. This can be used, for example, to skip chips that contain nodata values.
            verbose: If `False` we will be quiet.
        """

        if label_fns is None:
            self.fns = imagery_fns
            self.use_labels = False
        else:
            self.fns = list(zip(imagery_fns, label_fns)) 
            self.use_labels = True

        self.groups = groups

        self.chip_size = chip_size
        self.num_chips_per_tile = num_chips_per_tile
        self.windowed_sampling = windowed_sampling

        self.image_transform = image_transform
        self.label_transform = label_transform
        self.nodata_check = nodata_check

        self.verbose = verbose

        if self.verbose:
            print("Constructed StreamingGeospatialDataset")

    def stream_tile_fns(self):
        worker_info = torch.utils.data.get_worker_info()
        if worker_info is None: # In this case we are not loading through a DataLoader with multiple workers
            worker_id = 0
            num_workers = 1
        else:
            worker_id = worker_info.id
            num_workers = worker_info.num_workers

        # We only want to shuffle the order we traverse the files if we are the first worker (else, every worker will shuffle the files...)
        if worker_id == 0:
            np.random.shuffle(self.fns) # in place
        # NOTE: A warning, when different workers are created they will all have the same numpy random seed, however will have different torch random seeds. If you want to use numpy random functions, seed appropriately.
        #seed = torch.randint(low=0,high=2**32-1,size=(1,)).item()
        #np.random.seed(seed) # when different workers spawn, they have the same numpy random seed...

        if self.verbose:
            print("Creating a filename stream for worker %d" % (worker_id))

        # This logic splits up the list of filenames into `num_workers` chunks. Each worker will recieve ceil(num_filenames / num_workers) filenames to generate chips from. If the number of workers doesn't divide the number of filenames evenly then the last worker will have fewer filenames.
        N = len(self.fns)
        num_files_per_worker = int(np.ceil(N / num_workers))
        lower_idx = worker_id * num_files_per_worker
        upper_idx = min(N, (worker_id+1) * num_files_per_worker)
        for idx in range(lower_idx, upper_idx):

            label_fn = None
            if self.use_labels:
                img_fn, label_fn = self.fns[idx]
            else:
                img_fn = self.fns[idx]

            if self.groups is not None:
                group = self.groups[idx]
            else:
                group = None

            if self.verbose:
                print("Worker %d, yielding file %d" % (worker_id, idx))

            yield (img_fn, label_fn, group)

    def stream_chips(self):
        for img_fn, label_fn, group in self.stream_tile_fns():
            num_skipped_chips = 0

            # Open file pointers
            img_fp = rasterio.open(img_fn, "r")
            label_fp = rasterio.open(label_fn, "r") if self.use_labels else None

            height, width = img_fp.shape
            if self.use_labels: # garuntee that our label mask has the same dimensions as our imagery
                t_height, t_width = label_fp.shape
                assert height == t_height and width == t_width


            # If we aren't in windowed sampling mode then we should read the entire tile up front
            img_data = None
            label_data = None
            try:
                if not self.windowed_sampling:
                    img_data = np.rollaxis(img_fp.read(), 0, 3)
                    if self.use_labels:
                        label_data = label_fp.read().squeeze() # assume the label geotiff has a single channel
            except RasterioError as e:
                print("WARNING: Error reading in entire file, skipping to the next file")
                continue

            for i in range(self.num_chips_per_tile):
                # Select the top left pixel of our chip randomly
                x = np.random.randint(0, width-self.chip_size)
                y = np.random.randint(0, height-self.chip_size)

                # Read imagery / labels
                img = None
                labels = None
                if self.windowed_sampling:
                    try:
                        img = np.rollaxis(img_fp.read(window=Window(x, y, self.chip_size, self.chip_size)), 0, 3)
                        print(img.shape)
                        if self.use_labels:
                            labels = label_fp.read(window=Window(x, y, self.chip_size, self.chip_size)).squeeze()
                    except RasterioError:
                        print("WARNING: Error reading chip from file, skipping to the next chip")
                        continue
                else:
                    img = img_data[y:y+self.chip_size, x:x+self.chip_size, :]
                    if self.use_labels:
                        labels = label_data[y:y+self.chip_size, x:x+self.chip_size]

                # Check for no data
                if self.nodata_check is not None:
                    if self.use_labels:
                        skip_chip = self.nodata_check(img, labels)
                    else:
                        skip_chip = self.nodata_check(img)

                    if skip_chip: # The current chip has been identified as invalid by the `nodata_check(...)` method
                        num_skipped_chips += 1
                        continue

                # Transform the imagery
                if self.image_transform is not None:
                    if self.groups is None:
                        img = self.image_transform(img)
                    else:
                        img = self.image_transform(img, group)
                else:
                    img = torch.from_numpy(img).squeeze()

                # Transform the labels
                if self.use_labels:
                    if self.label_transform is not None:
                        if self.groups is None:
                            labels = self.label_transform(labels)
                        else:
                            labels = self.label_transform(labels, group)
                    else:
                        labels = torch.from_numpy(labels).squeeze()


                # Note, that img should be a torch "Double" type (i.e. a np.float32) and labels should be a torch "Long" type (i.e. np.int64)
                if self.use_labels:
                    yield img, labels
                else:
                    yield img

            # Close file pointers
            img_fp.close()
            if self.use_labels:
                label_fp.close()

            if num_skipped_chips>0 and self.verbose:
                print("We skipped %d chips on %s" % (img_fn))

    def __iter__(self):
        if self.verbose:
            print("Creating a new StreamingGeospatialDataset iterator")
        return iter(self.stream_chips())

# %% [markdown]
# Hyper-parameters

# %%
NUM_WORKERS = 4
CHIP_SIZE = 32
PADDING = 28
assert PADDING % 2 == 0
HALF_PADDING = PADDING//2
CHIP_STRIDE = CHIP_SIZE - PADDING
batch_size = 32
CHIP_SIZE = 32
NUM_CHIPS_PER_TILE = 100

# %% [markdown]
# Data transformation

# %%
with rasterio.open(image_fn) as f:
  img = f.read(1)
  input_width, input_height = f.width, f.height
  input_profile = f.profile.copy()


dataset = StreamingGeospatialDataset(
        imagery_fns= image_fns, label_fns =label_fns, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
        image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )
dataloader = torch.utils.data.DataLoader(
      dataset,batch_size=batch_size,
      num_workers=NUM_WORKERS,
      pin_memory=True,
        )

# %% [markdown]
# Check the size of the dataset

# %%
dataiter = iter(dataloader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 4, 32, 32])
# torch.Size([32, 32, 32])

# %% [markdown]
# Color Maps

# %%
NAIP_2013_MEANS = np.array([117.00, 130.75, 122.50, 159.30])
NAIP_2013_STDS = np.array([38.16, 36.68, 24.30, 66.22])
NAIP_2017_MEANS = np.array([72.84,  86.83, 76.78, 130.82])
NAIP_2017_STDS = np.array([41.78, 34.66, 28.76, 58.95])
NLCD_CLASSES = [ 0, 11, 12, 21, 22, 23, 24, 31, 41, 42, 43, 52, 71, 81, 82, 90, 95] # 16 classes + 1 nodata class ("0"). Note that "12" is "Perennial Ice/Snow" and is not present in Maryland.

NLCD_CLASS_COLORMAP = { # Copied from the emebedded color table in the NLCD data files
    0:  (0, 0, 0, 255),
    11: (70, 107, 159, 255),
    12: (209, 222, 248, 255),
    21: (222, 197, 197, 255),
    22: (217, 146, 130, 255),
    23: (235, 0, 0, 255),
    24: (171, 0, 0, 255),
    31: (179, 172, 159, 255),
    41: (104, 171, 95, 255),
    42: (28, 95, 44, 255),
    43: (181, 197, 143, 255),
    52: (204, 184, 121, 255),
    71: (223, 223, 194, 255),
    81: (220, 217, 57, 255),
    82: (171, 108, 40, 255),
    90: (184, 217, 235, 255),
    95: (108, 159, 184, 255)
}

NLCD_IDX_COLORMAP = {
    idx: NLCD_CLASS_COLORMAP[c]
    for idx, c in enumerate(NLCD_CLASSES)
}

def get_nlcd_class_to_idx_map():
    nlcd_label_to_idx_map = []
    idx = 0
    for i in range(NLCD_CLASSES[-1]+1):
        if i in NLCD_CLASSES:
            nlcd_label_to_idx_map.append(idx)
            idx += 1
        else:
            nlcd_label_to_idx_map.append(0)
    nlcd_label_to_idx_map = np.array(nlcd_label_to_idx_map).astype(np.int64)
    return nlcd_label_to_idx_map

NLCD_CLASS_TO_IDX_MAP = get_nlcd_class_to_idx_map() # I do this computation on import for illustration (this could instead be a length 96 vector that is hardcoded here)


NLCD_IDX_TO_REDUCED_LC_MAP = np.array([
    4,#  0 No data 0
    0,#  1 Open Water
    4,#  2 Ice/Snow
    2,#  3 Developed Open Space
    3,#  4 Developed Low Intensity
    3,#  5 Developed Medium Intensity
    3,#  6 Developed High Intensity
    3,#  7 Barren Land
    1,#  8 Deciduous Forest
    1,#  9 Evergreen Forest
    1,# 10 Mixed Forest
    1,# 11 Shrub/Scrub
    2,# 12 Grassland/Herbaceous
    2,# 13 Pasture/Hay
    2,# 14 Cultivated Crops
    1,# 15 Woody Wetlands
    1,# 16 Emergent Herbaceious Wetlands
])

NLCD_IDX_TO_REDUCED_LC_ACCUMULATOR = np.array([
    [0,0,0,0,1],#  0 No data 0
    [1,0,0,0,0],#  1 Open Water
    [0,0,0,0,1],#  2 Ice/Snow
    [0,0,0,0,0],#  3 Developed Open Space
    [0,0,0,0,0],#  4 Developed Low Intensity
    [0,0,0,1,0],#  5 Developed Medium Intensity
    [0,0,0,1,0],#  6 Developed High Intensity
    [0,0,0,0,0],#  7 Barren Land
    [0,1,0,0,0],#  8 Deciduous Forest
    [0,1,0,0,0],#  9 Evergreen Forest
    [0,1,0,0,0],# 10 Mixed Forest
    [0,1,0,0,0],# 11 Shrub/Scrub
    [0,0,1,0,0],# 12 Grassland/Herbaceous
    [0,0,1,0,0],# 13 Pasture/Hay
    [0,0,1,0,0],# 14 Cultivated Crops
    [0,1,0,0,0],# 15 Woody Wetlands
    [0,1,0,0,0],# 16 Emergent Herbaceious Wetlands
])

# %% [markdown]
# ## FCN Model

# %%
import functools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class FCN(nn.Module):

    def __init__(self, num_input_channels, num_output_classes, num_filters=64):
        super(FCN,self).__init__()

        self.conv1 = nn.Conv2d(num_input_channels, num_filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.last =  nn.Conv2d(num_filters, num_output_classes, kernel_size=1, stride=1, padding=0)

    def forward(self,inputs):
        x = F.relu(self.conv1(inputs))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.last(x)
        return x

# %%
model = FCN(num_input_channels=4, num_output_classes=len(NLCD_CLASSES))
print(model)
# Out:
# FCN(
#   (conv1): Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (last): Conv2d(64, 17, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ## Model training

# %%
model = model
optimizer = optim.AdamW(model.parameters(), lr=0.00001, amsgrad=True)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
epochs = 50
num_batches= 32

# %%
epoch = epochs
for epoch in range(epoch):
    losses = []
    for batch_idx, (data, targets) in tqdm(enumerate(dataloader), total=num_batches, file=sys.stdout):
    
        #optimizer.zero_grad()
        # get the inputs; data is a list of [inputs, labels]

        output = model(data)
        #print(output)
        #print(targets)
        print('the shape of output is',(output.shape))
        print('the shape of x is',data.shape)
        print('the shape of y is',targets.shape)
        #loss = criterion(output, torch.max(y, 1)[1])
        loss = criterion(output,targets)
        losses.append(loss.item())
        # zero the parameter gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        print("Loss at {}th epoch: {}".format(epoch,np.mean(losses)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss at 31th epoch: 0.9275615992290633
#  88%|████████▊ | 28/32 [00:35<00:03,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9183620553592156
#  91%|█████████ | 29/32 [00:35<00:02,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9446533252795537
#  94%|█████████▍| 30/32 [00:36<00:01,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9380706019939915
#  97%|█████████▋| 31/32 [00:37<00:00,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9319556532427669
# 100%|██████████| 32/32 [00:38<00:00,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9152861111091845
# 33it [00:39,  1.02it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9464705341002521
# 34it [00:40,  1.00it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9363785999161857
# 35it [00:42,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9301713920301862
# 36it [00:43,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9281465346748764
# 37it [00:44,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9442143236335955
# 38it [00:44,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9431915069237734
# 39it [00:45,  1.18it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 31th epoch: 0.9472677439451218
# 40it [00:45,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9440453183360216
# 41it [00:46,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.962130320923669
# 42it [00:47,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9585489797037702
# 43it [00:48,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9610759792002764
# 44it [00:49,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9711416655116611
# 45it [00:50,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9728445786496868
# 46it [00:52,  1.20s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9691512090094546
# 47it [00:53,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9797071653107802
# 48it [00:53,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9800918223906536
# 49it [00:55,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9842984366416931
# 50it [00:56,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9897504741070318
# 51it [00:57,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9916610373900487
# 52it [00:58,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.992133100077791
# 53it [00:59,  1.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0013053152296278
# 54it [01:00,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0097254493019798
# 55it [01:01,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0149880754096168
# 56it [01:02,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0207718840816564
# 57it [01:03,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0193373458138828
# 58it [01:03,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0302256628618403
# 59it [01:04,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0375867784023285
# 60it [01:05,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0344564602023265
# 61it [01:05,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.0437495650783661
# 62it [01:06,  1.38it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.047830239174858
# 63it [01:07,  1.40it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 1.043690700083971
# 64it [01:07,  1.42it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 31th epoch: 1.0486544278951793
# 65it [01:08,  1.59it/s]the shape of output is torch.Size([21, 17, 32, 32])
# the shape of x is torch.Size([21, 4, 32, 32])
# the shape of y is torch.Size([21, 32, 32])
# Loss at 31th epoch: 1.058041836276199
# 66it [01:08,  1.74it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 31th epoch: 1.0504574135168274
# 67it [01:09,  1.04s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8989482522010803
#   3%|▎         | 1/32 [00:08<04:36,  8.93s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9206336438655853
#   6%|▋         | 2/32 [00:09<03:13,  6.46s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0416369636853535
#   9%|▉         | 3/32 [00:10<02:17,  4.73s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9758579879999161
#  12%|█▎        | 4/32 [00:11<01:38,  3.52s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9188251852989197
#  16%|█▌        | 5/32 [00:11<01:12,  2.68s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.912595252195994
#  19%|█▉        | 6/32 [00:12<00:54,  2.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9108178274972099
#  22%|██▏       | 7/32 [00:13<00:43,  1.75s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.911109521985054
#  25%|██▌       | 8/32 [00:14<00:36,  1.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.891201568974389
#  28%|██▊       | 9/32 [00:15<00:34,  1.48s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9227595508098603
#  31%|███▏      | 10/32 [00:17<00:32,  1.46s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9373467672954906
#  34%|███▍      | 11/32 [00:19<00:33,  1.62s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9494579086701075
#  38%|███▊      | 12/32 [00:20<00:29,  1.48s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9499784891421978
#  41%|████      | 13/32 [00:21<00:24,  1.28s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9629005023411342
#  44%|████▍     | 14/32 [00:21<00:19,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9516931176185608
#  47%|████▋     | 15/32 [00:22<00:16,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9580515436828136
#  50%|█████     | 16/32 [00:23<00:14,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9434106875868404
#  53%|█████▎    | 17/32 [00:23<00:12,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9482984244823456
#  56%|█████▋    | 18/32 [00:24<00:11,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9194417987999163
#  59%|█████▉    | 19/32 [00:25<00:10,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9125191912055015
#  62%|██████▎   | 20/32 [00:26<00:10,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.906352813754763
#  66%|██████▌   | 21/32 [00:28<00:11,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9168567156249826
#  69%|██████▉   | 22/32 [00:29<00:11,  1.14s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9173330962657928
#  72%|███████▏  | 23/32 [00:30<00:10,  1.22s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.923063900321722
#  75%|███████▌  | 24/32 [00:32<00:10,  1.31s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9194276821613312
#  78%|███████▊  | 25/32 [00:33<00:07,  1.14s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9406430686895664
#  81%|████████▏ | 26/32 [00:33<00:06,  1.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9303360526208524
#  84%|████████▍ | 27/32 [00:34<00:04,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9251666015812329
#  88%|████████▊ | 28/32 [00:35<00:03,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9160243653017899
#  91%|█████████ | 29/32 [00:35<00:02,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9421930680672328
#  94%|█████████▍| 30/32 [00:36<00:01,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9356291303711552
#  97%|█████████▋| 31/32 [00:37<00:00,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9295631283894181
# 100%|██████████| 32/32 [00:38<00:00,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9129294500206456
# 33it [00:39,  1.07it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9439411531476414
# 34it [00:40,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9338408708572388
# 35it [00:41,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9276653114292357
# 36it [00:42,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9257266908078581
# 37it [00:43,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9417047531981217
# 38it [00:44,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9407765162296784
# 39it [00:45,  1.12it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 32th epoch: 0.9449330687522888
# 40it [00:45,  1.40it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9416984058007961
# 41it [00:46,  1.38it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.959710609345209
# 42it [00:47,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9561650254005609
# 43it [00:48,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9586996652863242
# 44it [00:49,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9687335226270888
# 45it [00:50,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9704802502756533
# 46it [00:52,  1.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9667581522718389
# 47it [00:53,  1.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9772926717996597
# 48it [00:54,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9777058362960815
# 49it [00:55,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9818593573570251
# 50it [00:56,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9872758154775582
# 51it [00:57,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9891939323682052
# 52it [00:58,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9896500290564771
# 53it [00:59,  1.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9988032513194613
# 54it [01:00,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0072993170131337
# 55it [01:01,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0126166258539473
# 56it [01:02,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0184031641274167
# 57it [01:03,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0170193417318936
# 58it [01:03,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0278417882272752
# 59it [01:04,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0351858218510945
# 60it [01:05,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.03206419358488
# 61it [01:05,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.041285805163845
# 62it [01:06,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0453503453542317
# 63it [01:07,  1.41it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 1.0412118276581168
# 64it [01:07,  1.43it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 32th epoch: 1.0462237734061022
# 65it [01:08,  1.62it/s]the shape of output is torch.Size([21, 17, 32, 32])
# the shape of x is torch.Size([21, 4, 32, 32])
# the shape of y is torch.Size([21, 32, 32])
# Loss at 32th epoch: 1.0556522219470053
# 66it [01:08,  1.74it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 32th epoch: 1.0480719244302208
# 67it [01:09,  1.03s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8966265916824341
#   3%|▎         | 1/32 [00:08<04:37,  8.97s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9186891615390778
#   6%|▋         | 2/32 [00:09<03:14,  6.48s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0398690104484558
#   9%|▉         | 3/32 [00:10<02:17,  4.75s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9737004339694977
#  12%|█▎        | 4/32 [00:11<01:38,  3.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9169413328170777
#  16%|█▌        | 5/32 [00:11<01:12,  2.68s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9107540349165598
#  19%|█▉        | 6/32 [00:12<00:54,  2.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.908896267414093
#  22%|██▏       | 7/32 [00:13<00:43,  1.74s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9091852307319641
#  25%|██▌       | 8/32 [00:14<00:36,  1.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8893409503830804
#  28%|██▊       | 9/32 [00:15<00:31,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9207820951938629
#  31%|███▏      | 10/32 [00:16<00:30,  1.40s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9352653947743502
#  34%|███▍      | 11/32 [00:18<00:30,  1.43s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.947380597392718
#  38%|███▊      | 12/32 [00:19<00:27,  1.38s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9479068013337942
#  41%|████      | 13/32 [00:20<00:25,  1.37s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9606665756021228
#  44%|████▍     | 14/32 [00:21<00:21,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9495390971501668
#  47%|████▋     | 15/32 [00:22<00:17,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9558290839195251
#  50%|█████     | 16/32 [00:23<00:14,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9411441718830782
#  53%|█████▎    | 17/32 [00:23<00:12,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9460055894321866
#  56%|█████▋    | 18/32 [00:24<00:11,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9171851951824991
#  59%|█████▉    | 19/32 [00:25<00:10,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.91024159938097
#  62%|██████▎   | 20/32 [00:26<00:10,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9040467469465165
#  66%|██████▌   | 21/32 [00:27<00:10,  1.00it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9145706363699653
#  69%|██████▉   | 22/32 [00:28<00:11,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9150731887506403
#  72%|███████▏  | 23/32 [00:30<00:11,  1.32s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9208259992301464
#  75%|███████▌  | 24/32 [00:32<00:10,  1.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9172087037563323
#  78%|███████▊  | 25/32 [00:32<00:08,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9382744557582415
#  81%|████████▏ | 26/32 [00:33<00:06,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9280121138802281
#  84%|████████▍ | 27/32 [00:34<00:04,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9229266994765827
#  88%|████████▊ | 28/32 [00:35<00:03,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9138319029890257
#  91%|█████████ | 29/32 [00:35<00:02,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9398947387933732
#  94%|█████████▍| 30/32 [00:36<00:01,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9333530847103365
#  97%|█████████▋| 31/32 [00:37<00:00,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9273317651823163
# 100%|██████████| 32/32 [00:38<00:00,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9107301731904348
# 33it [00:39,  1.02it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9415898489601472
# 34it [00:40,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9314848755087172
# 35it [00:41,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9253401416871283
# 36it [00:42,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9234845130830198
# 37it [00:43,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9393735159384576
# 38it [00:44,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9385321881526556
# 39it [00:46,  1.16s/it]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 33th epoch: 0.9427597172558307
# 40it [00:46,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9395144690827626
# 41it [00:47,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9574509326900754
# 42it [00:48,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9539389021174852
# 43it [00:49,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9564818516373634
# 44it [00:50,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9664849221706391
# 45it [00:51,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9682724262061326
# 46it [00:54,  1.54s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9645234403458047
# 47it [00:55,  1.46s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9750358716895183
# 48it [00:56,  1.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9754766633315962
# 49it [00:58,  1.40s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9795776361227035
# 50it [01:00,  1.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9849613010883331
# 51it [01:01,  1.56s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9868861499887246
# 52it [01:03,  1.50s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9873278810168212
# 53it [01:04,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9964617882613782
# 54it [01:05,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0050282039425589
# 55it [01:05,  1.09s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0103955476411752
# 56it [01:06,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0161851241923214
# 57it [01:07,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0148485390276745
# 58it [01:08,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0256086532342232
# 59it [01:08,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0329345966378847
# 60it [01:09,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0298215986275283
# 61it [01:10,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.03897303487024
# 62it [01:10,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0430227456584809
# 63it [01:11,  1.41it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 1.0388859235681593
# 64it [01:12,  1.43it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 33th epoch: 1.0439462501269121
# 65it [01:12,  1.61it/s]the shape of output is torch.Size([21, 17, 32, 32])
# the shape of x is torch.Size([21, 4, 32, 32])
# the shape of y is torch.Size([21, 32, 32])
# Loss at 33th epoch: 1.0534135432857457
# 66it [01:13,  1.74it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 33th epoch: 1.0458393777484325
# 67it [01:13,  1.10s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8944507837295532
#   3%|▎         | 1/32 [00:09<04:41,  9.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9168654084205627
#   6%|▋         | 2/32 [00:09<03:16,  6.56s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 1.0382202466328938
#   9%|▉         | 3/32 [00:10<02:19,  4.79s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9716914594173431
#  12%|█▎        | 4/32 [00:11<01:39,  3.56s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9151844143867492
#  16%|█▌        | 5/32 [00:11<01:13,  2.71s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9090321858723959
#  19%|█▉        | 6/32 [00:12<00:55,  2.14s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.907091770853315
#  22%|██▏       | 7/32 [00:13<00:44,  1.78s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9073723405599594
#  25%|██▌       | 8/32 [00:14<00:36,  1.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8875831431812711
#  28%|██▊       | 9/32 [00:15<00:32,  1.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.918916791677475
#  31%|███▏      | 10/32 [00:16<00:29,  1.35s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9333118037744002
#  34%|███▍      | 11/32 [00:18<00:28,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9454307109117508
#  38%|███▊      | 12/32 [00:19<00:26,  1.31s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9459575322958139
#  41%|████      | 13/32 [00:20<00:22,  1.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9585632511547634
#  44%|████▍     | 14/32 [00:21<00:22,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9475136717160543
#  47%|████▋     | 15/32 [00:22<00:20,  1.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9537383951246738
#  50%|█████     | 16/32 [00:23<00:16,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.93901127576828
#  53%|█████▎    | 17/32 [00:24<00:13,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9438503086566925
#  56%|█████▋    | 18/32 [00:24<00:12,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9150675895966982
#  59%|█████▉    | 19/32 [00:25<00:11,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9081027373671532
#  62%|██████▎   | 20/32 [00:27<00:11,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.901877475636346
#  66%|██████▌   | 21/32 [00:28<00:11,  1.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9124167927286841
#  69%|██████▉   | 22/32 [00:29<00:11,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9129462695640066
#  72%|███████▏  | 23/32 [00:31<00:13,  1.49s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.918721773972114
#  75%|███████▌  | 24/32 [00:32<00:10,  1.28s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9151221883296966
#  78%|███████▊  | 25/32 [00:33<00:07,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9360452007788879
#  81%|████████▏ | 26/32 [00:34<00:05,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9258271974545939
#  84%|████████▍ | 27/32 [00:34<00:04,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9208238327077457
#  88%|████████▊ | 28/32 [00:35<00:03,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9117715800630635
#  91%|█████████ | 29/32 [00:36<00:02,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9377326001723607
#  94%|█████████▍| 30/32 [00:37<00:01,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9312142297144859
#  97%|█████████▋| 31/32 [00:38<00:00,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9252352016046643
# 100%|██████████| 32/32 [00:39<00:00,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9086643303885604
# 33it [00:40,  1.04it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9393790986608056
# 34it [00:41,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9292714382920947
# 35it [00:42,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9231559460361799
# 36it [00:43,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9213800406133806
# 37it [00:43,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9371858278387472
# 38it [00:44,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9364259831416302
# 39it [00:45,  1.06it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 34th epoch: 0.9407171554863453
# 40it [00:46,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9374642248560743
# 41it [00:47,  1.28it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.955328514888173
# 42it [00:48,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9518479753372281
# 43it [00:49,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9543986625292085
# 44it [00:50,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9643736316098107
# 45it [00:51,  1.16s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9661988933449206
# 46it [00:53,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9624251070174765
# 47it [00:53,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9729192623247703
# 48it [00:54,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9733865400966333
# 49it [00:55,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9774379295110702
# ...
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 1.0100964054465293
# 60it [01:03,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 1.0070940446658212
# 61it [01:03,  1.40it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 1.0154012359919087
# 62it [01:04,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 1.0192871240396348
# 63it [01:05,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 1.0151736014522612
# 64it [01:05,  1.46it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 48th epoch: 1.0207427726342129
# 65it [01:06,  1.64it/s]the shape of output is torch.Size([21, 17, 32, 32])
# the shape of x is torch.Size([21, 4, 32, 32])
# the shape of y is torch.Size([21, 32, 32])
# Loss at 48th epoch: 1.030638852354252
# 66it [01:06,  1.77it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 48th epoch: 1.023208774292647
# 67it [01:07,  1.00s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8731866478919983
#   3%|▎         | 1/32 [00:08<04:32,  8.78s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9003491401672363
#   6%|▋         | 2/32 [00:09<03:10,  6.35s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0245705048243205
#   9%|▉         | 3/32 [00:10<02:14,  4.65s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9542159289121628
#  12%|█▎        | 4/32 [00:10<01:36,  3.45s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8995633721351624
#  16%|█▌        | 5/32 [00:11<01:10,  2.62s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8930852214495341
#  19%|█▉        | 6/32 [00:12<00:53,  2.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8898616007396153
#  22%|██▏       | 7/32 [00:13<00:42,  1.69s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.88971396535635
#  25%|██▌       | 8/32 [00:14<00:35,  1.48s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8702584173944261
#  28%|██▊       | 9/32 [00:15<00:32,  1.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9006398379802704
#  31%|███▏      | 10/32 [00:16<00:29,  1.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9143906344066967
#  34%|███▍      | 11/32 [00:18<00:30,  1.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9260526647170385
#  38%|███▊      | 12/32 [00:19<00:28,  1.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9261195201140183
#  41%|████      | 13/32 [00:20<00:24,  1.31s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9374765157699585
#  44%|████▍     | 14/32 [00:21<00:20,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.927109956741333
#  47%|████▋     | 15/32 [00:21<00:16,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9326204806566238
#  50%|█████     | 16/32 [00:22<00:14,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9170759530628428
#  53%|█████▎    | 17/32 [00:23<00:12,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9217074745231204
#  56%|█████▋    | 18/32 [00:23<00:11,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8930097567407709
#  59%|█████▉    | 19/32 [00:24<00:10,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.885644581913948
#  62%|██████▎   | 20/32 [00:25<00:10,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8785761566389174
#  66%|██████▌   | 21/32 [00:27<00:11,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8894912790168416
#  69%|██████▉   | 22/32 [00:28<00:11,  1.16s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8904905241468678
#  72%|███████▏  | 23/32 [00:30<00:12,  1.42s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.896276501317819
#  75%|███████▌  | 24/32 [00:31<00:09,  1.22s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.892826611995697
#  78%|███████▊  | 25/32 [00:32<00:07,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9128401164825146
#  81%|████████▏ | 26/32 [00:32<00:05,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9030934616371438
#  84%|████████▍ | 27/32 [00:33<00:04,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8989356820072446
#  88%|████████▊ | 28/32 [00:34<00:03,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.890273051015262
#  91%|█████████ | 29/32 [00:34<00:02,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9155324002106985
#  94%|█████████▍| 30/32 [00:35<00:01,  1.28it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9095192993840864
#  97%|█████████▋| 31/32 [00:36<00:00,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9037433099001646
# 100%|██████████| 32/32 [00:37<00:00,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.887267676266757
# 33it [00:38,  1.09it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9167871440158171
# 34it [00:39,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9068205986704145
# 35it [00:40,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9007731493976381
# 36it [00:41,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8998399521853473
# 37it [00:42,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.915087994776274
# 38it [00:43,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9151061620467749
# 39it [00:44,  1.07s/it]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 49th epoch: 0.9198477804660797
# 40it [00:45,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9165545905508646
# 41it [00:45,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9339250326156616
# 42it [00:46,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9307319244673086
# 43it [00:47,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9332582693208348
# 44it [00:49,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9429022881719801
# 45it [00:50,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9450226827808048
# 46it [00:51,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9410857545568588
# 47it [00:52,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9513980075716972
# 48it [00:53,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9521954655647278
# 49it [00:54,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9557440674304962
# 50it [00:54,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9607823000234716
# 51it [00:55,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9627425223588943
# 52it [00:57,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9630751767248478
# 53it [00:58,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9719280379789846
# 54it [00:59,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.981127877668901
# 55it [01:00,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9869522409779685
# 56it [01:01,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9927037326913131
# 57it [01:02,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.991871394987764
# 58it [01:02,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0018967541597656
# 59it [01:03,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0089431633551915
# 60it [01:04,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0059897157012438
# 61it [01:04,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.014223292950661
# 62it [01:05,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0181083225068592
# 63it [01:06,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 1.0140204625204206
# 64it [01:06,  1.45it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 49th epoch: 1.0196240067481994
# 65it [01:07,  1.63it/s]the shape of output is torch.Size([21, 17, 32, 32])
# the shape of x is torch.Size([21, 4, 32, 32])
# the shape of y is torch.Size([21, 32, 32])
# Loss at 49th epoch: 1.0295021217880826
# 66it [01:07,  1.78it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 49th epoch: 1.0220994193162491
# 67it [01:08,  1.02s/it]

# %%
predictions = output.detach().numpy()
predictions.shape
# Out:
# (22, 17, 32, 32)

# %% [markdown]
# # Visualize and save prediction results

# %%
from google.colab import files
import pickle
# function to save the predictions
def features_pickeled(input_features, results):
  input_features = input_features + '.npy'
  pickle.dump(results, open(input_features, 'wb'))
  files.download(input_features)

# %%
predictions_20 = '/content/drive/MyDrive/Data/DFC_2021/predictions'
features_pickeled(predictions_20, predictions)

# %%
pred = output.detach().numpy()
pred.shape
pred1 = pred[1,:,:,:]
pred1.shape
# Out:
# (17, 32, 32)

# %%
output = pred1 / pred1.sum(axis=0, keepdims=True)
output = (output * 255).astype(np.uint8)
output_dir = '/content/drive/MyDrive/Data/DFC_2021'

output_profile = input_profile.copy()
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = 1
output_profile["nodata"] = 0

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  f.write(output)
  f.write_colormap(1,NLCD_IDX_COLORMAP)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-6fce3d23c164> in <module>()
#      14
#      15 with rasterio.open(output_fn, "w", **output_profile) as f:
# ---> 16   f.write(output)
#      17   f.write_colormap(1,NLCD_IDX_COLORMAP)
#
# rasterio/_io.pyx in rasterio._io.DatasetWriterBase.write()
#
# ValueError: Source shape (17, 32, 32) is inconsistent with given indexes 1

# %% [markdown]
# # Evaluation
