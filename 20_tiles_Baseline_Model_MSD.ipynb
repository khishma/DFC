# %% [markdown]
# # One tile

# %% [markdown]
# ## Utils

# %%
# !pip install fiona
# !pip install rasterio
# !pip install tqdm
# Out:
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/37/94/4910fd55246c1d963727b03885ead6ef1cd3748a465f7b0239ab25dfc9a3/Fiona-1.8.18-cp36-cp36m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 313kB/s
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fiona) (2020.12.5)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona) (7.1.2)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona) (1.15.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona) (20.3.0)
# Installing collected packages: click-plugins, munch, cligj, fiona
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 munch-2.5.0
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/33/1a/51baddc8581ead98fcef591624b4b2521b581943a9178912a2ac576e0235/rasterio-1.1.8-1-cp36-cp36m-manylinux1_x86_64.whl (18.3MB)
#      |████████████████████████████████| 18.3MB 259kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.19.5)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from rasterio) (0.7.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from rasterio) (20.3.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from rasterio) (7.1.2)
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Installing collected packages: affine, snuggs, rasterio
# Successfully installed affine-2.3.0 rasterio-1.1.8 snuggs-1.4.7
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
import rasterio 
import matplotlib.pyplot as plt
import numpy as np
import fiona
import pandas as pd
import torch
torch.backends.cudnn.benchmark = True
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import datetime
from tqdm import tqdm
from torchvision.transforms import transforms
import os
import sys
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.errors import RasterioError, RasterioIOError
import torch 
from torchvision import transforms
from torch.utils.data.dataset import IterableDataset

# %%
#Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Split data in to train and validation

# %% [markdown]
# Using NLCD as labels, train with both years at the same time

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)
        
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_both.csv", index=False)

# %% [markdown]
# Using NLCD as labels, train with a single year at a time
#
# 2013 NAIP, 2013 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv", index=False)

# %% [markdown]
# 2017 NAIP, 2017 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2017.csv", index=False)

# %% [markdown]
# ## Dataset Loader

# %% [markdown]
# TileDataset

# %%
import numpy as np

import rasterio
from rasterio.windows import Window
from rasterio.errors import RasterioIOError

import torch
from torch.utils.data.dataset import Dataset

class TileInferenceDataset(Dataset):
    
    def __init__(self, fn, chip_size, stride, transform=None, windowed_sampling=False, verbose=False):
        """A torch Dataset for sampling a grid of chips that covers an input tile. 
        
        If `chip_size` doesn't divide the height of the tile evenly (which is what is likely to happen) then we will sample an additional row of chips that are aligned to the bottom of the file.
        We do a similar operation if `chip_size` doesn't divide the width of the tile evenly -- by appending an additional column.
        
        Note: without a `transform` we will return chips in (height, width, channels) format in whatever the tile's dtype is.
        
        Args:
            fn: The path to the file to sample from (this can be anything that rasterio.open(...) knows how to read).
            chip_size: The size of chips to return (chips will be squares).
            stride: How much we move the sliding window to sample the next chip. If this is is less than `chip_size` then we will get overlapping windows, if it is > `chip_size` then some parts of the tile will not be sampled.
            transform: A torchvision Transform to apply on each chip.
            windowed_sample: If `True` we will use rasterio.windows.Window to sample chips without every loading the entire file into memory, else, we will load the entire tile up-front and index into it to sample chips.
            verbose: Flag to control printing stuff.
        """
        self.fn = fn
        self.chip_size = chip_size
        
        self.transform = transform
        self.transform = transforms.Compose([transforms.ToTensor()])
        self.windowed_sampling = windowed_sampling
        self.verbose = verbose
        
        with rasterio.open(self.fn) as f:
            height, width = f.height, f.width
            self.num_channels = f.count
            self.dtype = f.profile["dtype"]
            if not windowed_sampling: # if we aren't using windowed sampling, then go ahead and read in all of the data
                self.data = np.rollaxis(f.read(), 0, 3)
            
        self.chip_coordinates = [] # upper left coordinate (y,x), of each chip that this Dataset will return
        for y in list(range(0, height - self.chip_size, stride)) + [height - self.chip_size]:
            for x in list(range(0, width - self.chip_size, stride)) + [width - self.chip_size]:
                self.chip_coordinates.append((y,x))
        self.num_chips = len(self.chip_coordinates)

        if self.verbose:
            print("Constructed TileInferenceDataset -- we have %d by %d file with %d channels with a dtype of %s. We are sampling %d chips from it." % (
                height, width, self.num_channels, self.dtype, self.num_chips
            ))
            
    def __getitem__(self, idx):
        '''
        Returns:
            A tuple (chip, (y,x)): `chip` is the chip that we sampled from the larger tile. (y,x) are the indices of the upper left corner of the chip.
        '''
        y, x = self.chip_coordinates[idx]
        
        if self.windowed_sampling:
            try:
                with rasterio.Env():
                    with rasterio.open(self.fn) as f:
                        img = np.rollaxis(f.read(window=rasterio.windows.Window(x, y, self.chip_size, self.chip_size)), 0, 3)
                        pritn(img)
            except RasterioIOError as e: # NOTE(caleb): I put this here to catch weird errors that I was seeing occasionally when trying to read from COGS - I don't remember the details though
                print("Reading %d failed, returning 0's" % (idx))
                img = np.zeros((self.chip_size, self.chip_size, self.num_channels), dtype=np.uint8)
        else:
            img = self.data[y:y+self.chip_size, x:x+self.chip_size]


        if self.transform is not None:
            img = self.transform(img)
        
        return img, np.array((y,x))
        
    def __len__(self):
        return self.num_chips

# %%
#-------------------
    # Run on each line in the input
    #-------------------
input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'

input_dataframe = pd.read_csv(input_fn,usecols = ['image_fn'], nrows=21 )
#input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
#groups = input_dataframe["group"].values


lst = []
for image_idx in range(len(image_fns)):
  tic = time.time()
  image_fn = image_fns[image_idx]
  group = groups[image_idx]
  lst.append(image_fn)
  print(lst)


  print("(%d/%d) Processing %s" % (image_idx, len(image_fns), image_fn), end=" ... ")
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif']
# (0/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif']
# (1/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif']
# (2/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif']
# (3/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif']
# (4/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif']
# (5/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif']
# (6/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif']
# (7/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif']
# (8/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif']
# (9/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif']
# (10/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif']
# (11/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif']
# (12/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif']
# (13/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif']
# (14/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif']
# (15/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif']
# (16/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif']
# (17/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif']
# (18/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif']
# (19/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif']
# (20/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif ...

# %%
class StreamingGeospatialDataset(IterableDataset):
    
    def __init__(self, imagery_fns, label_fns=None, groups=None, chip_size=32, num_chips_per_tile=200, windowed_sampling=False, image_transform=None, label_transform=None, nodata_check=None, verbose=False):
        """A torch Dataset for randomly sampling chips from a list of tiles. When used in conjunction with a DataLoader that has `num_workers>1` this Dataset will assign each worker to sample chips from disjoint sets of tiles.
        Args:
            imagery_fns: A list of filenames (or URLS -- anything that `rasterio.open()` can read) pointing to imagery tiles.
            label_fns: A list of filenames of the same size as `imagery_fns` pointing to label mask tiles or `None` if the Dataset should operate in "imagery only mode". Note that we expect `imagery_fns[i]` and `label_fns[i]` to have the same dimension and coordinate system.
            groups: Optional: A list of integers of the same size as `imagery_fns` that gives the "group" membership of each tile. This can be used to normalize imagery from different groups differently.
            chip_size: Desired size of chips (in pixels).
            num_chips_per_tile: Desired number of chips to sample for each tile.
            windowed_sampling: Flag indicating whether we should sample each chip with a read using `rasterio.windows.Window` or whether we should read the whole tile into memory, then sample chips.
            image_transform: A function to apply to each image chip object. If this is `None`, then the only transformation applied to the loaded imagery will be to convert it to a `torch.Tensor`. If this is not `None`, then the function should return a `Torch.tensor`. Further, if `groups` is not `None` then the transform function should expect the imagery as the first argument and the group as the second argument.
            label_transform: Similar to image_transform, but applied to label chips.
            nodata_check: A method that will check an `(image_chip)` or `(image_chip, label_chip)` (if `label_fns` are provided) and return whether or not the chip should be skipped. This can be used, for example, to skip chips that contain nodata values.
            verbose: If `False` we will be quiet.
        """

        if label_fns is None:
            self.fns = imagery_fns
            self.use_labels = False
        else:
            self.fns = list(zip(imagery_fns, label_fns)) 
            self.use_labels = True

        self.groups = groups

        self.chip_size = chip_size
        self.num_chips_per_tile = num_chips_per_tile
        self.windowed_sampling = windowed_sampling

        self.image_transform = image_transform
        self.label_transform = label_transform
        self.nodata_check = nodata_check

        self.verbose = verbose

        if self.verbose:
            print("Constructed StreamingGeospatialDataset")

    def stream_tile_fns(self):
        worker_info = torch.utils.data.get_worker_info()
        if worker_info is None: # In this case we are not loading through a DataLoader with multiple workers
            worker_id = 0
            num_workers = 1
        else:
            worker_id = worker_info.id
            num_workers = worker_info.num_workers

        # We only want to shuffle the order we traverse the files if we are the first worker (else, every worker will shuffle the files...)
        if worker_id == 0:
            np.random.shuffle(self.fns) # in place
        # NOTE: A warning, when different workers are created they will all have the same numpy random seed, however will have different torch random seeds. If you want to use numpy random functions, seed appropriately.
        #seed = torch.randint(low=0,high=2**32-1,size=(1,)).item()
        #np.random.seed(seed) # when different workers spawn, they have the same numpy random seed...

        if self.verbose:
            print("Creating a filename stream for worker %d" % (worker_id))

        # This logic splits up the list of filenames into `num_workers` chunks. Each worker will recieve ceil(num_filenames / num_workers) filenames to generate chips from. If the number of workers doesn't divide the number of filenames evenly then the last worker will have fewer filenames.
        N = len(self.fns)
        num_files_per_worker = int(np.ceil(N / num_workers))
        lower_idx = worker_id * num_files_per_worker
        upper_idx = min(N, (worker_id+1) * num_files_per_worker)
        for idx in range(lower_idx, upper_idx):

            label_fn = None
            if self.use_labels:
                img_fn, label_fn = self.fns[idx]
            else:
                img_fn = self.fns[idx]

            if self.groups is not None:
                group = self.groups[idx]
            else:
                group = None

            if self.verbose:
                print("Worker %d, yielding file %d" % (worker_id, idx))

            yield (img_fn, label_fn, group)

    def stream_chips(self):
        for img_fn, label_fn, group in self.stream_tile_fns():
            num_skipped_chips = 0

            # Open file pointers
            img_fp = rasterio.open(img_fn, "r")
            label_fp = rasterio.open(label_fn, "r") if self.use_labels else None

            height, width = img_fp.shape
            if self.use_labels: # garuntee that our label mask has the same dimensions as our imagery
                t_height, t_width = label_fp.shape
                assert height == t_height and width == t_width


            # If we aren't in windowed sampling mode then we should read the entire tile up front
            img_data = None
            label_data = None
            try:
                if not self.windowed_sampling:
                    img_data = np.rollaxis(img_fp.read(), 0, 3)
                    if self.use_labels:
                        label_data = label_fp.read().squeeze() # assume the label geotiff has a single channel
            except RasterioError as e:
                print("WARNING: Error reading in entire file, skipping to the next file")
                continue

            for i in range(self.num_chips_per_tile):
                # Select the top left pixel of our chip randomly
                x = np.random.randint(0, width-self.chip_size)
                y = np.random.randint(0, height-self.chip_size)

                # Read imagery / labels
                img = None
                labels = None
                if self.windowed_sampling:
                    try:
                        img = np.rollaxis(img_fp.read(window=Window(x, y, self.chip_size, self.chip_size)), 0, 3)
                        print(img.shape)
                        if self.use_labels:
                            labels = label_fp.read(window=Window(x, y, self.chip_size, self.chip_size)).squeeze()
                    except RasterioError:
                        print("WARNING: Error reading chip from file, skipping to the next chip")
                        continue
                else:
                    img = img_data[y:y+self.chip_size, x:x+self.chip_size, :]
                    if self.use_labels:
                        labels = label_data[y:y+self.chip_size, x:x+self.chip_size]

                # Check for no data
                if self.nodata_check is not None:
                    if self.use_labels:
                        skip_chip = self.nodata_check(img, labels)
                    else:
                        skip_chip = self.nodata_check(img)

                    if skip_chip: # The current chip has been identified as invalid by the `nodata_check(...)` method
                        num_skipped_chips += 1
                        continue

                # Transform the imagery
                if self.image_transform is not None:
                    if self.groups is None:
                        img = self.image_transform(img)
                    else:
                        img = self.image_transform(img, group)
                else:
                    img = torch.from_numpy(img).squeeze()

                # Transform the labels
                if self.use_labels:
                    if self.label_transform is not None:
                        if self.groups is None:
                            labels = self.label_transform(labels)
                        else:
                            labels = self.label_transform(labels, group)
                    else:
                        labels = torch.from_numpy(labels).squeeze()


                # Note, that img should be a torch "Double" type (i.e. a np.float32) and labels should be a torch "Long" type (i.e. np.int64)
                if self.use_labels:
                    yield img, labels
                else:
                    yield img

            # Close file pointers
            img_fp.close()
            if self.use_labels:
                label_fp.close()

            if num_skipped_chips>0 and self.verbose:
                print("We skipped %d chips on %s" % (img_fn))

    def __iter__(self):
        if self.verbose:
            print("Creating a new StreamingGeospatialDataset iterator")
        return iter(self.stream_chips())

# %% [markdown]
# Creating color map

# %%
input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'
batch_size = 32

input_dataframe = pd.read_csv(input_fn, nrows=21 )
#input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
print(image_fns)
label_fns = input_dataframe["label_fn"].values
print(label_fns)
groups = input_dataframe["group"].values
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif']
# ['https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/546_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/597_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/596_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/595_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/541_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/497_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/496_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/545_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/544_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/543_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/542_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1033_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1032_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1031_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1030_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1083_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1082_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1081_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/979_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/978_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/977_nlcd-2013.tif']

# %% [markdown]
# Hyper-parameters

# %%
NUM_WORKERS = 4
CHIP_SIZE = 32
PADDING = 28
assert PADDING % 2 == 0
HALF_PADDING = PADDING//2
CHIP_STRIDE = CHIP_SIZE - PADDING
batch_size = 32
CHIP_SIZE = 32
NUM_CHIPS_PER_TILE = 100

# %% [markdown]
# Transform Data

# %%
def image_transforms(img, group):
    if group == 0:
        img = (img - NAIP_2013_MEANS) / NAIP_2013_STDS
    elif group == 1:
        img = (img - NAIP_2017_MEANS) / NAIP_2017_STDS
    else:
        raise ValueError("group not recognized")
    img = np.rollaxis(img, 2, 0).astype(np.float32)
    img = torch.from_numpy(img)
    return img

def label_transforms(labels, group):
    labels = NLCD_CLASS_TO_IDX_MAP[labels]
    labels = torch.from_numpy(labels)
    return labels

def nodata_check(img, labels):
    return np.any(labels == 0) or np.any(np.sum(img == 0, axis=2) == 4)

# %% [markdown]
# DataLoader

# %%
with rasterio.open(image_fn) as f:
  img = f.read(1)
  input_width, input_height = f.width, f.height
  input_profile = f.profile.copy()
dataset = StreamingGeospatialDataset(
        imagery_fns= lst, label_fns =label_fns, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
        image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )
dataloader = torch.utils.data.DataLoader(
      dataset,batch_size=batch_size,
      num_workers=NUM_WORKERS,
      pin_memory=True,
        )

# %% [markdown]
# Check the size of the dataset

# %%
dataiter = iter(dataloader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7f0a38fbf50b> in <module>()
#       1 dataiter = iter(dataloader)
# ----> 2 images, labels = dataiter.next()
#       3 print(images.shape)
#       4 print(labels.shape)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1083             else:
#    1084                 del self._task_info[idx]
# -> 1085                 return self._process_data(data)
#    1086
#    1087     def _try_put_index(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1109         self._try_put_index()
#    1110         if isinstance(data, ExceptionWrapper):
# -> 1111             data.reraise()
#    1112         return data
#    1113
#
# /usr/local/lib/python3.6/dist-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# NameError: Caught NameError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/worker.py", line 198, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py", line 28, in fetch
#     data.append(next(self.dataset_iter))
#   File "<ipython-input-11-fd02b06ab9be>", line 146, in stream_chips
#     img = self.image_transform(img, group)
#   File "<ipython-input-20-88a3d0e48437>", line 3, in image_transforms
#     img = (img - NAIP_2013_MEANS) / NAIP_2013_STDS
# NameError: name 'NAIP_2013_MEANS' is not defined

# %% [markdown]
# Copying the propertieds of the image

# %%
with rasterio.open(image_fn) as f:
  print(f.shape)
  input_width, input_height = f.width, f.height
  input_profile = f.profile.copy()
# Out:
# (3880, 3880)

# %% [markdown]
# ## FCN Model

# %%
import functools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class FCN(nn.Module):

    def __init__(self, num_input_channels, num_output_classes, num_filters=64):
        super(FCN,self).__init__()

        self.conv1 = nn.Conv2d(num_input_channels, num_filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.last =  nn.Conv2d(num_filters, num_output_classes, kernel_size=1, stride=1, padding=0)

    def forward(self,inputs):
        x = F.relu(self.conv1(inputs))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.last(x)
        return x

# %%
model = FCN(num_input_channels=4, num_output_classes=len(NLCD_CLASSES))
print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-36fb29d28d94> in <module>()
# ----> 1 model = FCN(num_input_channels=4, num_output_classes=len(NLCD_CLASSES))
#       2 print(model)
#
# NameError: name 'NLCD_CLASSES' is not defined

# %% [markdown]
# ## Model training

# %%
model = model
optimizer = optim.AdamW(model.parameters(), lr=0.00001, amsgrad=True)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
epochs = 50
num_batches= 32

# %%
epoch = epochs
for epoch in range(epoch):
    losses = []
    for batch_idx, (data, targets) in tqdm(enumerate(dataloader), total=num_batches, file=sys.stdout):
    
        #optimizer.zero_grad()
        # get the inputs; data is a list of [inputs, labels]

        output = model(data)
        #print(output)
        #print(targets)
        print('the shape of output is',(output.shape))
        print('the shape of x is',data.shape)
        print('the shape of y is',targets.shape)
        #loss = criterion(output, torch.max(y, 1)[1])
        loss = criterion(output,targets)
        losses.append(loss.item())
        # zero the parameter gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        print("Loss at {}th epoch: {}".format(epoch,np.mean(losses)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss at 31th epoch: 0.8401385311569486
#  88%|████████▊ | 28/32 [00:34<00:03,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.8692714613059471
#  91%|█████████ | 29/32 [00:34<00:02,  1.31it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.8866002261638641
#  94%|█████████▍| 30/32 [00:35<00:01,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.8764490985101269
#  97%|█████████▋| 31/32 [00:36<00:00,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.8676420357078314
# 100%|██████████| 32/32 [00:37<00:00,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9006544875376152
# 33it [00:38,  1.12it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9236364276970134
# 34it [00:39,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9188151495797293
# 35it [00:40,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9122349040375816
# 36it [00:41,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9141095586725183
# 37it [00:42,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9300786037194101
# 38it [00:43,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9267200491367242
# 39it [00:44,  1.18it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 31th epoch: 0.9235132992267608
# 40it [00:44,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9193688834585795
# 41it [00:45,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9382393133072626
# 42it [00:46,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9432497689890307
# 43it [00:47,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.938625995408405
# 44it [00:48,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.946087470319536
# 45it [00:50,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9405490341393844
# 46it [00:51,  1.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9323113522631057
# 47it [00:51,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9452923933664957
# 48it [00:52,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9436969708423225
# 49it [00:53,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9403799915313721
# 50it [00:54,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9459151310079238
# 51it [00:54,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9515089874084179
# 52it [00:55,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9468289490016002
# 53it [00:57,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9554026910552272
# 54it [00:58,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9622444900599393
# 55it [00:59,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9584457118596349
# 56it [01:00,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9641226791498954
# 57it [01:01,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9667318144748951
# 58it [01:01,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9646490044512991
# 59it [01:02,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.966590964794159
# 60it [01:03,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9642797434916262
# 61it [01:03,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9627342454848751
# 62it [01:04,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9738685687383016
# 63it [01:04,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 31th epoch: 0.9706870764493942
# 64it [01:05,  1.47it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 31th epoch: 0.9713146356435922
# 65it [01:06,  1.66it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 31th epoch: 0.971906764940782
# 66it [01:06,  1.78it/s]the shape of output is torch.Size([23, 17, 32, 32])
# the shape of x is torch.Size([23, 4, 32, 32])
# the shape of y is torch.Size([23, 32, 32])
# Loss at 31th epoch: 0.9651314891985993
# 67it [01:07,  1.00s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.5734431147575378
#   3%|▎         | 1/32 [00:08<04:26,  8.61s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.7244375348091125
#   6%|▋         | 2/32 [00:09<03:06,  6.22s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8238954544067383
#   9%|▉         | 3/32 [00:09<02:12,  4.55s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.798714205622673
#  12%|█▎        | 4/32 [00:10<01:34,  3.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.7268094897270203
#  16%|█▌        | 5/32 [00:11<01:09,  2.57s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.815786232550939
#  19%|█▉        | 6/32 [00:11<00:52,  2.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8718899062701634
#  22%|██▏       | 7/32 [00:12<00:41,  1.66s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8500762730836868
#  25%|██▌       | 8/32 [00:13<00:34,  1.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8025739722781711
#  28%|██▊       | 9/32 [00:14<00:31,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.7733958780765533
#  31%|███▏      | 10/32 [00:16<00:29,  1.34s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8130422884767706
#  34%|███▍      | 11/32 [00:17<00:29,  1.40s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.7842825278639793
#  38%|███▊      | 12/32 [00:19<00:28,  1.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.7903424295095297
#  41%|████      | 13/32 [00:20<00:24,  1.31s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8139183925730842
#  44%|████▍     | 14/32 [00:20<00:20,  1.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8000693301359812
#  47%|████▋     | 15/32 [00:21<00:16,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8049510885030031
#  50%|█████     | 16/32 [00:22<00:14,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8011766724726733
#  53%|█████▎    | 17/32 [00:22<00:12,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.826438855793741
#  56%|█████▋    | 18/32 [00:23<00:11,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8131577011786009
#  59%|█████▉    | 19/32 [00:24<00:10,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8203997388482094
#  62%|██████▎   | 20/32 [00:25<00:11,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8073954454490117
#  66%|██████▌   | 21/32 [00:27<00:11,  1.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8180583593520251
#  69%|██████▉   | 22/32 [00:28<00:12,  1.29s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.803518225317416
#  72%|███████▏  | 23/32 [00:30<00:11,  1.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8088377664486567
#  75%|███████▌  | 24/32 [00:31<00:09,  1.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.822105565071106
#  78%|███████▊  | 25/32 [00:31<00:07,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8565324728305523
#  81%|████████▏ | 26/32 [00:32<00:05,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8426384373947426
#  84%|████████▍ | 27/32 [00:33<00:04,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8385996052197048
#  88%|████████▊ | 28/32 [00:33<00:03,  1.28it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8676867443939735
#  91%|█████████ | 29/32 [00:34<00:02,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8849015315373738
#  94%|█████████▍| 30/32 [00:35<00:01,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8747521677324849
#  97%|█████████▋| 31/32 [00:36<00:00,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.8659709487110376
# 100%|██████████| 32/32 [00:37<00:00,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.898973589593714
# 33it [00:38,  1.14it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9218292884966907
# 34it [00:39,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9170342326164246
# 35it [00:40,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9104626841015286
# 36it [00:41,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9123733494732831
# 37it [00:42,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.928283082811456
# 38it [00:43,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9249760432121081
# 39it [00:43,  1.17it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 32th epoch: 0.921782948076725
# 40it [00:44,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9176619430867637
# 41it [00:44,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9364937118121556
# 42it [00:45,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9415651088537171
# 43it [00:46,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9369622672146017
# 44it [00:47,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9443715850512187
# 45it [00:49,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9388585479363151
# 46it [00:50,  1.16s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9306548149027722
# 47it [00:51,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.943569449086984
# 48it [00:52,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9420038899596856
# 49it [00:52,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9387200176715851
# 50it [00:53,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.944235153057996
# 51it [00:54,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9498591136473876
# 52it [00:55,  1.00it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9451963867781297
# 53it [00:57,  1.12s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9537559427596904
# 54it [00:58,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9606328736652028
# 55it [00:59,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9568249593888011
# 56it [01:00,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9625170889653658
# 57it [01:00,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9651417783622084
# 58it [01:01,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9630467669438507
# 59it [01:02,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9649704615275065
# 60it [01:02,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9626671202847215
# 61it [01:03,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9611093334613308
# 62it [01:04,  1.44it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.972230609447237
# 63it [01:04,  1.47it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 32th epoch: 0.9690689565613866
# 64it [01:05,  1.49it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 32th epoch: 0.9696810328043424
# 65it [01:05,  1.66it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 32th epoch: 0.9702575414469747
# 66it [01:06,  1.79it/s]the shape of output is torch.Size([23, 17, 32, 32])
# the shape of x is torch.Size([23, 4, 32, 32])
# the shape of y is torch.Size([23, 32, 32])
# Loss at 32th epoch: 0.9634939040710677
# 67it [01:06,  1.00it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.5723665952682495
#   3%|▎         | 1/32 [00:09<04:40,  9.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7235186398029327
#   6%|▋         | 2/32 [00:09<03:15,  6.52s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.822897215684255
#   9%|▉         | 3/32 [00:10<02:18,  4.76s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7974792569875717
#  12%|█▎        | 4/32 [00:11<01:38,  3.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7255245268344879
#  16%|█▌        | 5/32 [00:11<01:12,  2.67s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8143987109263738
#  19%|█▉        | 6/32 [00:12<00:54,  2.09s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8706010963235583
#  22%|██▏       | 7/32 [00:13<00:42,  1.71s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8487541191279888
#  25%|██▌       | 8/32 [00:14<00:35,  1.49s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8012857536474863
#  28%|██▊       | 9/32 [00:15<00:33,  1.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7721398085355758
#  31%|███▏      | 10/32 [00:16<00:31,  1.43s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8118111735040491
#  34%|███▍      | 11/32 [00:18<00:32,  1.56s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7829780355095863
#  38%|███▊      | 12/32 [00:20<00:30,  1.50s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7890600218222692
#  41%|████      | 13/32 [00:20<00:24,  1.27s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8125771858862468
#  44%|████▍     | 14/32 [00:21<00:19,  1.09s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7987728933493297
#  47%|████▋     | 15/32 [00:22<00:16,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8036679308861494
#  50%|█████     | 16/32 [00:22<00:14,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.7999206553487217
#  53%|█████▎    | 17/32 [00:23<00:12,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8250218149688509
#  56%|█████▋    | 18/32 [00:24<00:11,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.81180623801131
#  59%|█████▉    | 19/32 [00:25<00:10,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8190505757927895
#  62%|██████▎   | 20/32 [00:26<00:11,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8060820429098039
#  66%|██████▌   | 21/32 [00:27<00:11,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8167084929617968
#  69%|██████▉   | 22/32 [00:29<00:11,  1.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8022022545337677
#  72%|███████▏  | 23/32 [00:31<00:12,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8075255590180556
#  75%|███████▌  | 24/32 [00:31<00:09,  1.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8207818257808686
#  78%|███████▊  | 25/32 [00:32<00:07,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8550110172766906
#  81%|████████▏ | 26/32 [00:33<00:05,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8411468179137619
#  84%|████████▍ | 27/32 [00:33<00:04,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8371295311621257
#  88%|████████▊ | 28/32 [00:34<00:03,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8661742847541283
#  91%|█████████ | 29/32 [00:35<00:02,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8832796355088551
#  94%|█████████▍| 30/32 [00:35<00:01,  1.31it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8731320750328803
#  97%|█████████▋| 31/32 [00:36<00:00,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8643744476139545
# 100%|██████████| 32/32 [00:37<00:00,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.8973684563781276
# 33it [00:38,  1.10it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9201041284729453
# 34it [00:39,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9153350506510053
# 35it [00:41,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9087724553214179
# 36it [00:42,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9107164515031351
# 37it [00:43,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9265699621878172
# 38it [00:43,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9233112258788867
# 39it [00:44,  1.21it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 33th epoch: 0.9201309591531753
# 40it [00:44,  1.50it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9160330193798717
# 41it [00:45,  1.47it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9348265173889342
# 42it [00:46,  1.34it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9399554216584494
# 43it [00:47,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9353718974373557
# 44it [00:48,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9427318917380438
# 45it [00:49,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9372446498145228
# 46it [00:50,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9290729989396765
# 47it [00:51,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9419252549608549
# 48it [00:52,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9403885724593182
# 49it [00:53,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9371345794200897
# 50it [00:54,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.942630345914878
# 51it [00:55,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9482833662858376
# 52it [00:56,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9436370258061391
# 53it [00:57,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9521804948647817
# 54it [00:58,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.959091124751351
# 55it [00:59,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9552754248891558
# 56it [01:00,  1.04s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.960981992253086
# 57it [01:01,  1.08it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9636222864019459
# 58it [01:02,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9615148578659963
# 59it [01:02,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9634213397900263
# 60it [01:03,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.961125801821224
# 61it [01:04,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9595555509290388
# 62it [01:04,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9706664880116781
# 63it [01:05,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 33th epoch: 0.9675236670300364
# 64it [01:05,  1.47it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 33th epoch: 0.9681201045329754
# 65it [01:06,  1.66it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 33th epoch: 0.9686824182669321
# 66it [01:06,  1.78it/s]the shape of output is torch.Size([23, 17, 32, 32])
# the shape of x is torch.Size([23, 4, 32, 32])
# the shape of y is torch.Size([23, 32, 32])
# Loss at 33th epoch: 0.9619306156884379
# 67it [01:07,  1.01s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.5713075995445251
#   3%|▎         | 1/32 [00:08<04:20,  8.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.722632646560669
#   6%|▋         | 2/32 [00:09<03:02,  6.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8219602505366007
#   9%|▉         | 3/32 [00:09<02:09,  4.45s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7963038682937622
#  12%|█▎        | 4/32 [00:10<01:32,  3.32s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7242961227893829
#  16%|█▌        | 5/32 [00:11<01:08,  2.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8130833556254705
#  19%|█▉        | 6/32 [00:11<00:51,  1.98s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8693845995834896
#  22%|██▏       | 7/32 [00:12<00:40,  1.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8474981002509594
#  25%|██▌       | 8/32 [00:13<00:34,  1.42s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8000614874892764
#  28%|██▊       | 9/32 [00:14<00:31,  1.36s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7709463089704514
#  31%|███▏      | 10/32 [00:15<00:29,  1.32s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8106443854895505
#  34%|███▍      | 11/32 [00:17<00:30,  1.47s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7817348539829254
#  38%|███▊      | 12/32 [00:19<00:28,  1.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7878375190954942
#  41%|████      | 13/32 [00:19<00:23,  1.26s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8112981617450714
#  44%|████▍     | 14/32 [00:20<00:19,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7975368420283
#  47%|████▋     | 15/32 [00:21<00:16,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8024429157376289
#  50%|█████     | 16/32 [00:21<00:13,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.7987243322765126
#  53%|█████▎    | 17/32 [00:22<00:12,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8236699402332306
#  56%|█████▋    | 18/32 [00:23<00:10,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8105139261797855
#  59%|█████▉    | 19/32 [00:24<00:10,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8177599638700486
#  62%|██████▎   | 20/32 [00:25<00:10,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8048268386295864
#  66%|██████▌   | 21/32 [00:26<00:10,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8154198744080283
#  69%|██████▉   | 22/32 [00:27<00:11,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8009455307670261
#  72%|███████▏  | 23/32 [00:29<00:11,  1.26s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8062709818283716
#  75%|███████▌  | 24/32 [00:30<00:10,  1.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8195177555084229
#  78%|███████▊  | 25/32 [00:31<00:07,  1.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8535564312568078
#  81%|████████▏ | 26/32 [00:32<00:05,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8397196994887458
#  84%|████████▍ | 27/32 [00:32<00:04,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8357232617480415
#  88%|████████▊ | 28/32 [00:33<00:03,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.864729052987592
#  91%|█████████ | 29/32 [00:34<00:02,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8817303717136383
#  94%|█████████▍| 30/32 [00:34<00:01,  1.28it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8715844808086273
#  97%|█████████▋| 31/32 [00:35<00:00,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8628478720784187
# 100%|██████████| 32/32 [00:36<00:00,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.8958345471006451
# 33it [00:37,  1.12it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9184563861173742
# 34it [00:39,  1.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9137133768626622
# 35it [00:39,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9071584128671222
# 36it [00:40,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9091334858456174
# 37it [00:41,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9249351087369417
# 38it [00:42,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9217209418614706
# 39it [00:43,  1.17it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 34th epoch: 0.9185469359159469
# 40it [00:43,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9144712788302723
# 41it [00:44,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9332257267974672
# 42it [00:45,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.938408961129743
# 43it [00:46,  1.11it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9338434677232396
# 44it [00:47,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9411559886402554
# 45it [00:49,  1.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9356957233470419
# 46it [00:50,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9275546302186682
# 47it [00:51,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9403478801250458
# 48it [00:51,  1.10it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.9388392020244988
# 49it [00:52,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 34th epoch: 0.935612096786499
# ...
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 0.9448238586386045
# 60it [01:03,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 0.942617803812027
# 61it [01:04,  1.38it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 0.9408756105169174
# 62it [01:04,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 0.9519241267726535
# 63it [01:05,  1.44it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 48th epoch: 0.9489926365204155
# 64it [01:06,  1.45it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 48th epoch: 0.9493755601919615
# 65it [01:06,  1.64it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 48th epoch: 0.9498019340363416
# 66it [01:07,  1.75it/s]the shape of output is torch.Size([23, 17, 32, 32])
# the shape of x is torch.Size([23, 4, 32, 32])
# the shape of y is torch.Size([23, 32, 32])
# Loss at 48th epoch: 0.9432093843595305
# 67it [01:07,  1.01s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.5565724968910217
#   3%|▎         | 1/32 [00:09<04:46,  9.23s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7109582424163818
#   6%|▋         | 2/32 [00:09<03:19,  6.65s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8103714386622111
#   9%|▉         | 3/32 [00:10<02:20,  4.86s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7814957648515701
#  12%|█▎        | 4/32 [00:11<01:40,  3.59s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7087146699428558
#  16%|█▌        | 5/32 [00:11<01:13,  2.72s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7972337951262792
#  19%|█▉        | 6/32 [00:12<00:55,  2.12s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8547109663486481
#  22%|██▏       | 7/32 [00:13<00:43,  1.74s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8322206772863865
#  25%|██▌       | 8/32 [00:14<00:36,  1.51s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7851056059201559
#  28%|██▊       | 9/32 [00:15<00:31,  1.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7563127547502517
#  31%|███▏      | 10/32 [00:16<00:29,  1.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.796401091597297
#  34%|███▍      | 11/32 [00:17<00:27,  1.29s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7664220680793127
#  38%|███▊      | 12/32 [00:19<00:28,  1.42s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7727470077001132
#  41%|████      | 13/32 [00:20<00:26,  1.38s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7956686658518655
#  44%|████▍     | 14/32 [00:21<00:21,  1.22s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.782369335492452
#  47%|████▋     | 15/32 [00:22<00:17,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7873225621879101
#  50%|█████     | 16/32 [00:23<00:15,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.784021233811098
#  53%|█████▎    | 17/32 [00:23<00:12,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.80721315741539
#  56%|█████▋    | 18/32 [00:24<00:11,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7945795059204102
#  59%|█████▉    | 19/32 [00:25<00:10,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8018705278635025
#  62%|██████▎   | 20/32 [00:26<00:10,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7893308599789938
#  66%|██████▌   | 21/32 [00:27<00:11,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7996976511044935
#  69%|██████▉   | 22/32 [00:29<00:12,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7855570044206537
#  72%|███████▏  | 23/32 [00:31<00:12,  1.35s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.7908828941484293
#  75%|███████▌  | 24/32 [00:32<00:09,  1.23s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8040541875362396
#  78%|███████▊  | 25/32 [00:32<00:07,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8359166601529489
#  81%|████████▏ | 26/32 [00:33<00:05,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8223142513522396
#  84%|████████▍ | 27/32 [00:34<00:04,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8185342571565083
#  88%|████████▊ | 28/32 [00:34<00:03,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8471046377872599
#  91%|█████████ | 29/32 [00:35<00:02,  1.31it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8630365868409474
#  94%|█████████▍| 30/32 [00:36<00:01,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8529402652094441
#  97%|█████████▋| 31/32 [00:37<00:00,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8443720266222954
# 100%|██████████| 32/32 [00:37<00:00,  1.19it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8773569663365682
# 33it [00:38,  1.13it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8988034023958094
# 34it [00:40,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8943379861967904
# 35it [00:41,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8878617551591661
# 36it [00:42,  1.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8901629383499557
# 37it [00:43,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.905398008070494
# 38it [00:43,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.902644123786535
# 39it [00:44,  1.16it/s]the shape of output is torch.Size([12, 17, 32, 32])
# the shape of x is torch.Size([12, 4, 32, 32])
# the shape of y is torch.Size([12, 32, 32])
# Loss at 49th epoch: 0.899484233558178
# 40it [00:44,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.8956874667144403
# 41it [00:45,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9139569231442043
# 42it [00:46,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.919692596723867
# 43it [00:47,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9152806902473624
# 44it [00:49,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9221412062644958
# 45it [00:50,  1.12s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9170432699763257
# 46it [00:51,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9092207018365251
# 47it [00:52,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9214075021445751
# 48it [00:52,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.920226880482265
# 49it [00:53,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9172122061252594
# 50it [00:54,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9224785320899066
# 51it [00:55,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9284763714441886
# 52it [00:56,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9240303838028098
# 53it [00:58,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9322495648154506
# 54it [00:59,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9395277229222384
# 55it [01:00,  1.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9356347705636706
# 56it [01:01,  1.03it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9414305854261967
# 57it [01:01,  1.14it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9442822337150574
# 58it [01:02,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9419891662516836
# 59it [01:03,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9437396814425786
# 60it [01:03,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9415370235677625
# 61it [01:04,  1.41it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.93978349335732
# 62it [01:05,  1.44it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9508319516030569
# 63it [01:05,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 49th epoch: 0.9479103852063417
# 64it [01:06,  1.47it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 49th epoch: 0.9482801336508531
# 65it [01:06,  1.65it/s]the shape of output is torch.Size([22, 17, 32, 32])
# the shape of x is torch.Size([22, 4, 32, 32])
# the shape of y is torch.Size([22, 32, 32])
# Loss at 49th epoch: 0.9487003982067108
# 66it [01:07,  1.75it/s]the shape of output is torch.Size([23, 17, 32, 32])
# the shape of x is torch.Size([23, 4, 32, 32])
# the shape of y is torch.Size([23, 32, 32])
# Loss at 49th epoch: 0.9421166492931878
# 67it [01:07,  1.01s/it]

# %%
output.shape
# Out:
# torch.Size([23, 17, 32, 32])

# %%
output = output / output.sum(axis=0, keepdims=True)
output = (output * 255).astype(np.uint8)

output_profile = input_profile.copy()
  
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = len(NLCD_CLASSES)
del output_profile["nodata"]

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions-soft")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  print(f.shape)
  f.write(output.astype(rasterio.uint8))

# %%
output_dir = '/content/drive/MyDrive/Data/DFC_2021'

output_profile = input_profile.copy()
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = 1
output_profile["nodata"] = 0

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  f.write(output_hard, 1)
  f.write_colormap(1,NLCD_IDX_COLORMAP)

# %%
pred = output.detach().numpy()
#np.save(pred, '/content/drive/MyDrive/Data/DFC_2021/predictions.npy')

# %%
output_dir = '/content/drive/MyDrive/Data/DFC_2021'

output_profile = input_profile.copy()
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = 1
output_profile["nodata"] = 0

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  f.write(output_hard, 1)
  f.write_colormap(1,NLCD_IDX_COLORMAP)
# Out:
# dtype('float32')

# %%
prediction = output[1,:,:,:]
prediction = output.detach().numpy()
prediction.shape
print(prediction.dtype)
prediction = prediction / prediction.sum(axis=0, keepdims=True)
prediction = (prediction * 255).astype(np.uint8)
prediction.shape
# Out:
# float32
# (23, 17, 32, 32)

# %%
prediction = prediction[1,:,:,:]
prediction = prediction / prediction.sum(axis=0, keepdims=True)
prediction = (prediction * 255).astype(np.uint8)
prediction.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-c731693909fc> in <module>()
# ----> 1 prediction = prediction[1,:,:,:]
#       2 prediction = prediction / prediction.sum(axis=0, keepdims=True)
#       3 prediction = (prediction * 255).astype(np.uint8)
#       4 prediction.shape
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
output_dir = '/content/drive/MyDrive/Data/DFC_2021'

output_profile = input_profile.copy()
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = 1
output_profile["nodata"] = 0

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  f.write(output_hard, 1)
  f.write_colormap(1,NLCD_IDX_COLORMAP)
# Out:
# '\n#if args.save_soft:\n  output = output / output.sum(axis=0, keepdims=True)\n  output = (output * 255).astype(np.uint8)\n\n  output_profile = input_profile.copy()\n  output_profile["driver"] = "GTiff"\n  output_profile["dtype"] = "uint8"\n  output_profile["count"] = len(NLCD_CLASSES)\n  del output_profile["nodata"]\n\n  output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"\n  output_fn = output_fn.replace("naip", "predictions-soft")\n # output_fn = os.path.join(output_dir, output_fn)\n\n  with rasterio.open(output_fn, "w", **output_profile) as f:\n    print(f.shape)\n    f.write(output) '

# %%
output = output / output.sum(axis=0, keepdims=True)
output = (output * 255).astype(np.uint8)

output_profile = input_profile.copy()
  
output_profile["driver"] = "GTiff"
output_profile["dtype"] = "uint8"
output_profile["count"] = len(NLCD_CLASSES)
del output_profile["nodata"]

output_fn = image_fn.split("/")[-1] # something like "546_naip-2013.tif"
output_fn = output_fn.replace("naip", "predictions-soft")
output_fn = os.path.join(output_dir, output_fn)

with rasterio.open(output_fn, "w", **output_profile) as f:
  print(f.shape)
  f.write(output.astype(rasterio.uint8))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
# (3880, 3880)

# %% [markdown]
# # Streamline tiles

# %%
NAIP_2013_MEANS = np.array([117.00, 130.75, 122.50, 159.30])
NAIP_2013_STDS = np.array([38.16, 36.68, 24.30, 66.22])
NAIP_2017_MEANS = np.array([72.84,  86.83, 76.78, 130.82])
NAIP_2017_STDS = np.array([41.78, 34.66, 28.76, 58.95])
NLCD_CLASSES = [ 0, 11, 12, 21, 22, 23, 24, 31, 41, 42, 43, 52, 71, 81, 82, 90, 95] # 16 classes + 1 nodata class ("0"). Note that "12" is "Perennial Ice/Snow" and is not present in Maryland.

NLCD_CLASS_COLORMAP = { # Copied from the emebedded color table in the NLCD data files
    0:  (0, 0, 0, 255),
    11: (70, 107, 159, 255),
    12: (209, 222, 248, 255),
    21: (222, 197, 197, 255),
    22: (217, 146, 130, 255),
    23: (235, 0, 0, 255),
    24: (171, 0, 0, 255),
    31: (179, 172, 159, 255),
    41: (104, 171, 95, 255),
    42: (28, 95, 44, 255),
    43: (181, 197, 143, 255),
    52: (204, 184, 121, 255),
    71: (223, 223, 194, 255),
    81: (220, 217, 57, 255),
    82: (171, 108, 40, 255),
    90: (184, 217, 235, 255),
    95: (108, 159, 184, 255)
}

NLCD_IDX_COLORMAP = {
    idx: NLCD_CLASS_COLORMAP[c]
    for idx, c in enumerate(NLCD_CLASSES)
}

def get_nlcd_class_to_idx_map():
    nlcd_label_to_idx_map = []
    idx = 0
    for i in range(NLCD_CLASSES[-1]+1):
        if i in NLCD_CLASSES:
            nlcd_label_to_idx_map.append(idx)
            idx += 1
        else:
            nlcd_label_to_idx_map.append(0)
    nlcd_label_to_idx_map = np.array(nlcd_label_to_idx_map).astype(np.int64)
    return nlcd_label_to_idx_map

NLCD_CLASS_TO_IDX_MAP = get_nlcd_class_to_idx_map() # I do this computation on import for illustration (this could instead be a length 96 vector that is hardcoded here)


NLCD_IDX_TO_REDUCED_LC_MAP = np.array([
    4,#  0 No data 0
    0,#  1 Open Water
    4,#  2 Ice/Snow
    2,#  3 Developed Open Space
    3,#  4 Developed Low Intensity
    3,#  5 Developed Medium Intensity
    3,#  6 Developed High Intensity
    3,#  7 Barren Land
    1,#  8 Deciduous Forest
    1,#  9 Evergreen Forest
    1,# 10 Mixed Forest
    1,# 11 Shrub/Scrub
    2,# 12 Grassland/Herbaceous
    2,# 13 Pasture/Hay
    2,# 14 Cultivated Crops
    1,# 15 Woody Wetlands
    1,# 16 Emergent Herbaceious Wetlands
])

NLCD_IDX_TO_REDUCED_LC_ACCUMULATOR = np.array([
    [0,0,0,0,1],#  0 No data 0
    [1,0,0,0,0],#  1 Open Water
    [0,0,0,0,1],#  2 Ice/Snow
    [0,0,0,0,0],#  3 Developed Open Space
    [0,0,0,0,0],#  4 Developed Low Intensity
    [0,0,0,1,0],#  5 Developed Medium Intensity
    [0,0,0,1,0],#  6 Developed High Intensity
    [0,0,0,0,0],#  7 Barren Land
    [0,1,0,0,0],#  8 Deciduous Forest
    [0,1,0,0,0],#  9 Evergreen Forest
    [0,1,0,0,0],# 10 Mixed Forest
    [0,1,0,0,0],# 11 Shrub/Scrub
    [0,0,1,0,0],# 12 Grassland/Herbaceous
    [0,0,1,0,0],# 13 Pasture/Hay
    [0,0,1,0,0],# 14 Cultivated Crops
    [0,1,0,0,0],# 15 Woody Wetlands
    [0,1,0,0,0],# 16 Emergent Herbaceious Wetlands
])

# %% [markdown]
# ## Streamline DataLoader

# %%
class StreamingGeospatialDataset(IterableDataset):
    
    def __init__(self, imagery_fns, label_fns=None, groups=None, chip_size=256, num_chips_per_tile=200, windowed_sampling=False, image_transform=None, label_transform=None, nodata_check=None, verbose=False):
        """A torch Dataset for randomly sampling chips from a list of tiles. When used in conjunction with a DataLoader that has `num_workers>1` this Dataset will assign each worker to sample chips from disjoint sets of tiles.
        Args:
            imagery_fns: A list of filenames (or URLS -- anything that `rasterio.open()` can read) pointing to imagery tiles.
            label_fns: A list of filenames of the same size as `imagery_fns` pointing to label mask tiles or `None` if the Dataset should operate in "imagery only mode". Note that we expect `imagery_fns[i]` and `label_fns[i]` to have the same dimension and coordinate system.
            groups: Optional: A list of integers of the same size as `imagery_fns` that gives the "group" membership of each tile. This can be used to normalize imagery from different groups differently.
            chip_size: Desired size of chips (in pixels).
            num_chips_per_tile: Desired number of chips to sample for each tile.
            windowed_sampling: Flag indicating whether we should sample each chip with a read using `rasterio.windows.Window` or whether we should read the whole tile into memory, then sample chips.
            image_transform: A function to apply to each image chip object. If this is `None`, then the only transformation applied to the loaded imagery will be to convert it to a `torch.Tensor`. If this is not `None`, then the function should return a `Torch.tensor`. Further, if `groups` is not `None` then the transform function should expect the imagery as the first argument and the group as the second argument.
            label_transform: Similar to image_transform, but applied to label chips.
            nodata_check: A method that will check an `(image_chip)` or `(image_chip, label_chip)` (if `label_fns` are provided) and return whether or not the chip should be skipped. This can be used, for example, to skip chips that contain nodata values.
            verbose: If `False` we will be quiet.
        """

        if label_fns is None:
            self.fns = imagery_fns
            self.use_labels = False
        else:
            self.fns = list(zip(imagery_fns, label_fns)) 
            self.use_labels = True

        self.groups = groups

        self.chip_size = chip_size
        self.num_chips_per_tile = num_chips_per_tile
        self.windowed_sampling = windowed_sampling

        self.image_transform = image_transform
        self.label_transform = label_transform
        self.nodata_check = nodata_check

        self.verbose = verbose

        if self.verbose:
            print("Constructed StreamingGeospatialDataset")

    def stream_tile_fns(self):
        worker_info = torch.utils.data.get_worker_info()
        if worker_info is None: # In this case we are not loading through a DataLoader with multiple workers
            worker_id = 0
            num_workers = 1
        else:
            worker_id = worker_info.id
            num_workers = worker_info.num_workers

        # We only want to shuffle the order we traverse the files if we are the first worker (else, every worker will shuffle the files...)
        if worker_id == 0:
            np.random.shuffle(self.fns) # in place
        # NOTE: A warning, when different workers are created they will all have the same numpy random seed, however will have different torch random seeds. If you want to use numpy random functions, seed appropriately.
        #seed = torch.randint(low=0,high=2**32-1,size=(1,)).item()
        #np.random.seed(seed) # when different workers spawn, they have the same numpy random seed...

        if self.verbose:
            print("Creating a filename stream for worker %d" % (worker_id))

        # This logic splits up the list of filenames into `num_workers` chunks. Each worker will recieve ceil(num_filenames / num_workers) filenames to generate chips from. If the number of workers doesn't divide the number of filenames evenly then the last worker will have fewer filenames.
        N = len(self.fns)
        num_files_per_worker = int(np.ceil(N / num_workers))
        lower_idx = worker_id * num_files_per_worker
        upper_idx = min(N, (worker_id+1) * num_files_per_worker)
        for idx in range(lower_idx, upper_idx):

            label_fn = None
            if self.use_labels:
                img_fn, label_fn = self.fns[idx]
            else:
                img_fn = self.fns[idx]

            if self.groups is not None:
                group = self.groups[idx]
            else:
                group = None

            if self.verbose:
                print("Worker %d, yielding file %d" % (worker_id, idx))

            yield (img_fn, label_fn, group)

    def stream_chips(self):
        for img_fn, label_fn, group in self.stream_tile_fns():
            num_skipped_chips = 0

            # Open file pointers
            img_fp = rasterio.open(img_fn, "r")
            label_fp = rasterio.open(label_fn, "r") if self.use_labels else None

            height, width = img_fp.shape
            if self.use_labels: # garuntee that our label mask has the same dimensions as our imagery
                t_height, t_width = label_fp.shape
                assert height == t_height and width == t_width


            # If we aren't in windowed sampling mode then we should read the entire tile up front
            img_data = None
            label_data = None
            try:
                if not self.windowed_sampling:
                    img_data = np.rollaxis(img_fp.read(), 0, 3)
                    if self.use_labels:
                        label_data = label_fp.read().squeeze() # assume the label geotiff has a single channel
            except RasterioError as e:
                print("WARNING: Error reading in entire file, skipping to the next file")
                continue

            for i in range(self.num_chips_per_tile):
                # Select the top left pixel of our chip randomly
                x = np.random.randint(0, width-self.chip_size)
                y = np.random.randint(0, height-self.chip_size)

                # Read imagery / labels
                img = None
                labels = None
                if self.windowed_sampling:
                    try:
                        img = np.rollaxis(img_fp.read(window=Window(x, y, self.chip_size, self.chip_size)), 0, 3)
                        print(img.shape)
                        if self.use_labels:
                            labels = label_fp.read(window=Window(x, y, self.chip_size, self.chip_size)).squeeze()
                    except RasterioError:
                        print("WARNING: Error reading chip from file, skipping to the next chip")
                        continue
                else:
                    img = img_data[y:y+self.chip_size, x:x+self.chip_size, :]
                    if self.use_labels:
                        labels = label_data[y:y+self.chip_size, x:x+self.chip_size]

                # Check for no data
                if self.nodata_check is not None:
                    if self.use_labels:
                        skip_chip = self.nodata_check(img, labels)
                    else:
                        skip_chip = self.nodata_check(img)

                    if skip_chip: # The current chip has been identified as invalid by the `nodata_check(...)` method
                        num_skipped_chips += 1
                        continue

                # Transform the imagery
                if self.image_transform is not None:
                    if self.groups is None:
                        img = self.image_transform(img)
                    else:
                        img = self.image_transform(img, group)
                else:
                    img = torch.from_numpy(img).squeeze()

                # Transform the labels
                if self.use_labels:
                    if self.label_transform is not None:
                        if self.groups is None:
                            labels = self.label_transform(labels)
                        else:
                            labels = self.label_transform(labels, group)
                    else:
                        labels = torch.from_numpy(labels).squeeze()


                # Note, that img should be a torch "Double" type (i.e. a np.float32) and labels should be a torch "Long" type (i.e. np.int64)
                if self.use_labels:
                    yield img, labels
                else:
                    yield img

            # Close file pointers
            img_fp.close()
            if self.use_labels:
                label_fp.close()

            if num_skipped_chips>0 and self.verbose:
                print("We skipped %d chips on %s" % (img_fn))

    def __iter__(self):
        if self.verbose:
            print("Creating a new StreamingGeospatialDataset iterator")
        return iter(self.stream_chips())

# %%
NUM_WORKERS = 0
NUM_CHIPS_PER_TILE = 100
CHIP_SIZE = 32

NAIP_2013_MEANS = np.array([117.00, 130.75, 122.50, 159.30])
NAIP_2013_STDS = np.array([38.16, 36.68, 24.30, 66.22])
NAIP_2017_MEANS = np.array([72.84,  86.83, 76.78, 130.82])
NAIP_2017_STDS = np.array([41.78, 34.66, 28.76, 58.95])
NLCD_CLASSES = [ 0, 11, 12, 21, 22, 23, 24, 31, 41, 42, 43, 52, 71, 81, 82, 90, 95] # 16 classes + 1 nodata class ("0"). Note that "12" is "Perennial Ice/Snow" and is not present in Maryland.

NLCD_CLASS_COLORMAP = { # Copied from the emebedded color table in the NLCD data files
    0:  (0, 0, 0, 255),
    11: (70, 107, 159, 255),
    12: (209, 222, 248, 255),
    21: (222, 197, 197, 255),
    22: (217, 146, 130, 255),
    23: (235, 0, 0, 255),
    24: (171, 0, 0, 255),
    31: (179, 172, 159, 255),
    41: (104, 171, 95, 255),
    42: (28, 95, 44, 255),
    43: (181, 197, 143, 255),
    52: (204, 184, 121, 255),
    71: (223, 223, 194, 255),
    81: (220, 217, 57, 255),
    82: (171, 108, 40, 255),
    90: (184, 217, 235, 255),
    95: (108, 159, 184, 255)
}

NLCD_IDX_COLORMAP = {
    idx: NLCD_CLASS_COLORMAP[c]
    for idx, c in enumerate(NLCD_CLASSES)
}

def get_nlcd_class_to_idx_map():
    nlcd_label_to_idx_map = []
    idx = 0
    for i in range(NLCD_CLASSES[-1]+1):
        if i in NLCD_CLASSES:
            nlcd_label_to_idx_map.append(idx)
            idx += 1
        else:
            nlcd_label_to_idx_map.append(0)
    nlcd_label_to_idx_map = np.array(nlcd_label_to_idx_map).astype(np.int64)
    return nlcd_label_to_idx_map

NLCD_CLASS_TO_IDX_MAP = get_nlcd_class_to_idx_map() # I do this computation on import for illustration (this could instead be a length 96 vector that is hardcoded here)


NLCD_IDX_TO_REDUCED_LC_MAP = np.array([
    4,#  0 No data 0
    0,#  1 Open Water
    4,#  2 Ice/Snow
    2,#  3 Developed Open Space
    3,#  4 Developed Low Intensity
    3,#  5 Developed Medium Intensity
    3,#  6 Developed High Intensity
    3,#  7 Barren Land
    1,#  8 Deciduous Forest
    1,#  9 Evergreen Forest
    1,# 10 Mixed Forest
    1,# 11 Shrub/Scrub
    2,# 12 Grassland/Herbaceous
    2,# 13 Pasture/Hay
    2,# 14 Cultivated Crops
    1,# 15 Woody Wetlands
    1,# 16 Emergent Herbaceious Wetlands
])

NLCD_IDX_TO_REDUCED_LC_ACCUMULATOR = np.array([
    [0,0,0,0,1],#  0 No data 0
    [1,0,0,0,0],#  1 Open Water
    [0,0,0,0,1],#  2 Ice/Snow
    [0,0,0,0,0],#  3 Developed Open Space
    [0,0,0,0,0],#  4 Developed Low Intensity
    [0,0,0,1,0],#  5 Developed Medium Intensity
    [0,0,0,1,0],#  6 Developed High Intensity
    [0,0,0,0,0],#  7 Barren Land
    [0,1,0,0,0],#  8 Deciduous Forest
    [0,1,0,0,0],#  9 Evergreen Forest
    [0,1,0,0,0],# 10 Mixed Forest
    [0,1,0,0,0],# 11 Shrub/Scrub
    [0,0,1,0,0],# 12 Grassland/Herbaceous
    [0,0,1,0,0],# 13 Pasture/Hay
    [0,0,1,0,0],# 14 Cultivated Crops
    [0,1,0,0,0],# 15 Woody Wetlands
    [0,1,0,0,0],# 16 Emergent Herbaceious Wetlands
])


def image_transforms(img, group):
    if group == 0:
        img = (img - NAIP_2013_MEANS) / NAIP_2013_STDS
    elif group == 1:
        img = (img - NAIP_2017_MEANS) / NAIP_2017_STDS
    else:
        raise ValueError("group not recognized")
    img = np.rollaxis(img, 2, 0).astype(np.float32)
    img = torch.from_numpy(img)
    return img

def label_transforms(labels, group):
    labels = NLCD_CLASS_TO_IDX_MAP[labels]
    labels = torch.from_numpy(labels)
    return labels

def nodata_check(img, labels):
    return np.any(labels == 0) or np.any(np.sum(img == 0, axis=2) == 4)


def main():
    print("Starting DFC2021 baseline training script at %s" % (str(datetime.datetime.now())))

# %%
device = torch.device("cuda:0")
device
# Out:
# device(type='cuda', index=0)

# %%
#-------------------
# Load input data
#-------------------

input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'
batch_size = 32


input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
print(image_fns)
label_fns = input_dataframe["label_fn"].values
groups = input_dataframe["group"].values

#dataset = StreamingGeospatialDataset(
#imagery_fns=image_fns, label_fns=label_fns, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
#image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
#    )

dataset = StreamingGeospatialDataset(
imagery_fns=image_fns, label_fns=label_fns, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )

dataloader = torch.utils.data.DataLoader(
dataset,
batch_size= batch_size,
num_workers=NUM_WORKERS,
pin_memory=True,
    )
num_training_batches_per_epoch = int(len(image_fns) * NUM_CHIPS_PER_TILE / batch_size)
print("We will be training with %d batches per epoch" % (num_training_batches_per_epoch))
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif'
#  ...
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/549_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/548_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/547_naip-2013.tif']
# We will be training with 7031 batches per epoch

# %%
dataiter = iter(dataloader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 4, 32, 32])
# torch.Size([32, 32, 32])

# %% [markdown]
# ## FCN Model

# %%
import functools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class FCN(nn.Module):

    def __init__(self, num_input_channels, num_output_classes, num_filters=64):
        super(FCN,self).__init__()

        self.conv1 = nn.Conv2d(num_input_channels, num_filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.last =  nn.Conv2d(num_filters, num_output_classes, kernel_size=1, stride=1, padding=0)

    def forward(self,inputs):
        x = F.relu(self.conv1(inputs))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.last(x)
        return x

# %%
model = FCN(num_input_channels=4, num_output_classes=len(NLCD_CLASSES))
print(model)
# Out:
# FCN(
#   (conv1): Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (last): Conv2d(64, 17, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ## Training

# %%
model = model
optimizer = optim.AdamW(model.parameters(), lr=0.00001, amsgrad=True)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
epochs = 50
num_batches= 32
#print("Model has %d parameters" % (utils.count_parameters(model)))

# %%
epoch = epochs
for epoch in range(epoch):
    losses = []
    for batch_idx, (data, targets) in tqdm(enumerate(dataloader), total=num_batches, file=sys.stdout):
    
        #optimizer.zero_grad()
        # get the inputs; data is a list of [inputs, labels]

        output = model(data)
        #print(output)
        #print(targets)
        print('the shape of output is',(output.shape))
        print('the shape of x is',data.shape)
        print('the shape of y is',targets.shape)
        #loss = criterion(output, torch.max(y, 1)[1])
        loss = criterion(output,targets)
        losses.append(loss.item())
        # zero the parameter gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        print("Loss at {}th epoch: {}".format(epoch,np.mean(losses)))
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 2.1296398639678955
#
#
#
#
#
#   3%|▎         | 1/32 [00:05<02:46,  5.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 2.049004375934601
#
#
#
#
#
#   6%|▋         | 2/32 [00:06<01:58,  3.96s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 2.0114193757375083
#
#
#
#
#
#   9%|▉         | 3/32 [00:06<01:25,  2.96s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 2.000472068786621
#
#
#
#
#
#  12%|█▎        | 4/32 [00:10<01:31,  3.26s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.9609216690063476
#
#
#
#
#
#  16%|█▌        | 5/32 [00:11<01:06,  2.47s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.8563626805941265
#
#
#
#
#
#  19%|█▉        | 6/32 [00:16<01:23,  3.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.8079562016895838
#
#
#
#
#
#  22%|██▏       | 7/32 [00:16<01:00,  2.43s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7322159260511398
#
#
#
#
#
#  25%|██▌       | 8/32 [00:17<00:45,  1.89s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7287206384870741
#
#
#
#
#
#  28%|██▊       | 9/32 [00:22<01:02,  2.71s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7503467679023743
#
#
#
#
#
#  31%|███▏      | 10/32 [00:22<00:45,  2.09s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7608556205576116
#
#
#
#
#
#  34%|███▍      | 11/32 [00:23<00:34,  1.65s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7855940560499828
#
#
#
#
#
#  38%|███▊      | 12/32 [00:28<00:52,  2.61s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7841915625792284
#
#
#
#
#
#  41%|████      | 13/32 [00:28<00:38,  2.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.8089554224695479
#
#
#
#
#
#  44%|████▍     | 14/32 [00:29<00:29,  1.61s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.787147291501363
#
#
#
#
#
#  47%|████▋     | 15/32 [00:33<00:41,  2.46s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7107779309153557
#
#
#
#
#
#  50%|█████     | 16/32 [00:34<00:30,  1.91s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.640203248052036
#
#
#
#
#
#  53%|█████▎    | 17/32 [00:35<00:22,  1.52s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5975715948475733
#
#
#
#
#
#  56%|█████▋    | 18/32 [00:40<00:36,  2.58s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5993356987049705
#
#
#
#
#
#  59%|█████▉    | 19/32 [00:40<00:26,  2.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.606450679898262
#
#
#
#
#
#  62%|██████▎   | 20/32 [00:41<00:19,  1.59s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6049043990316845
#
#
#
#
#
#  66%|██████▌   | 21/32 [00:45<00:26,  2.40s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.603413768789985
#
#
#
#
#
#  69%|██████▉   | 22/32 [00:46<00:18,  1.86s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6012525843537373
#
#
#
#
#
#  72%|███████▏  | 23/32 [00:47<00:13,  1.50s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5960828090707462
#
#
#
#
#
#  75%|███████▌  | 24/32 [00:51<00:19,  2.42s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5801277041435242
#
#
#
#
#
#  78%|███████▊  | 25/32 [00:52<00:13,  1.88s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5521930616635542
#
#
#
#
#
#  81%|████████▏ | 26/32 [00:52<00:09,  1.51s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5462493256286338
#
#
#
#
#
#  84%|████████▍ | 27/32 [00:56<00:11,  2.28s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5437275362866265
#
#
#
#
#
#  88%|████████▊ | 28/32 [00:57<00:07,  1.79s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5418758988380432
#
#
#
#
#
#  91%|█████████ | 29/32 [00:58<00:04,  1.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5519841571648916
#
#
#
#
#
#  94%|█████████▍| 30/32 [00:58<00:02,  1.19s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.557017559005368
#
#
#
#
#
#  97%|█████████▋| 31/32 [01:05<00:02,  2.97s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5750149954110384
#
#
#
#
#
# 100%|██████████| 32/32 [01:06<00:00,  2.27s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5943058349869468
#
#
#
#
#
# 33it [01:07,  1.78s/it]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.5980935219456167
#
#
#
#
#
# 34it [01:12,  2.77s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6007260305540902
#
#
#
#
#
# 35it [01:12,  2.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6086272216505475
#
#
#
#
#
# 36it [01:13,  1.68s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6178105022456195
#
#
#
#
#
# 37it [01:18,  2.72s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6232974137130536
#
#
#
#
#
# 38it [01:19,  2.10s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6330808110726185
#
#
#
#
#
# 39it [01:19,  1.66s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6425953969359397
#
#
#
#
#
# 40it [01:24,  2.52s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.644529797681948
#
#
#
#
#
# 41it [01:25,  1.96s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.646032942192895
#
#
#
#
#
# 42it [01:25,  1.56s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6593157260916953
#
#
#
#
#
# 43it [01:31,  2.68s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6761235770854084
#
#
#
#
#
# 44it [01:31,  2.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.690054476261139
#
#
#
#
#
# 45it [01:32,  1.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7005196511745453
#
#
#
#
#
# 46it [01:37,  2.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6980429621452982
#
#
#
#
#
# 47it [01:37,  2.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6988943206767242
#
#
#
#
#
# 48it [01:38,  1.62s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6960153105307598
#
#
#
#
#
# 49it [01:43,  2.65s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6946677076816559
#
#
#
#
#
# 50it [01:44,  2.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6940327169848424
#
#
#
#
#
# 51it [01:44,  1.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6995661957905843
#
#
#
#
#
# 52it [01:50,  2.83s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7003127325255916
#
#
#
#
#
# 53it [01:51,  2.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7004312442408667
#
#
#
#
#
# 54it [01:51,  1.70s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.7011596993966536
#
#
#
#
#
# 55it [01:52,  1.38s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.686455823481083
#
#
#
#
#
# 56it [01:56,  2.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6700760638504697
#
#
#
#
#
# 57it [01:57,  1.82s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 0th epoch: 1.6562557652078826
#
#
#
#
#
# 58it [01:58,  1.46s/it]

# %%
def fit (model,data_loader, num_batches, optimizer, criterion, epoch, memo=''):
    model.train()
    
    losses = []
    tic = time.time()
    for batch_idx, (data, targets) in tqdm(enumerate(data_loader), total=num_batches, file=sys.stdout):
        data = data
        targets = targets
        
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, targets)
        losses.append(loss.item())
        loss.backward()
        optimizer.step()

    avg_loss = np.mean(losses)
    
    print('[{}] Training Epoch: {}\t Time elapsed: {:.2f} seconds\t Loss: {:.2f}'.format(
        memo, epoch, time.time()-tic, avg_loss), end=""
    )
    print("")
    
    return [avg_loss],output

# %%
fit(model,data_loader=dataloader, num_batches = batch_size, optimizer = optimizer, criterion =criterion, epoch = epochs, memo='')
# Out:
# 135it [04:56,  1.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-16a278b6f7ce> in <module>()
# ----> 1 fit(model,data_loader=dataloader, num_batches = batch_size, optimizer = optimizer, criterion =criterion, epoch = epochs, memo='')
#
# <ipython-input-30-668f97e22355> in fit(model, data_loader, num_batches, optimizer, criterion, epoch, memo)
#       4     losses = []
#       5     tic = time.time()
# ----> 6     for batch_idx, (data, targets) in tqdm(enumerate(data_loader), total=num_batches, file=sys.stdout):
#       7         data = data
#       8         targets = targets
#
# /usr/local/lib/python3.6/dist-packages/tqdm/std.py in __iter__(self)
#    1102                 fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1103
# -> 1104         for obj in iterable:
#    1105             yield obj
#    1106             # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      26             for _ in possibly_batched_index:
#      27                 try:
# ---> 28                     data.append(next(self.dataset_iter))
#      29                 except StopIteration:
#      30                     break
#
# <ipython-input-13-1f53b8b4ca05> in stream_chips(self)
#     101             try:
#     102                 if not self.windowed_sampling:
# --> 103                     img_data = np.rollaxis(img_fp.read(), 0, 3)
#     104                     if self.use_labels:
#     105                         label_data = label_fp.read().squeeze() # assume the label geotiff has a single channel
#
# KeyboardInterrupt:

# %%
import sys
import os
os.environ["CURL_CA_BUNDLE"] = "/etc/ssl/certs/ca-certificates.crt" # A workaround in case this happens: https://github.com/mapbox/rasterio/issues/1289
import time
import datetime
import argparse
import copy

import numpy as np
import pandas as pd

#from dataloaders.StreamingDatasets import StreamingGeospatialDataset

import torch
torch.backends.cudnn.deterministic = False
torch.backends.cudnn.benchmark = True
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import models
import utils

NUM_WORKERS = 4
NUM_CHIPS_PER_TILE = 100
CHIP_SIZE = 256


def image_transforms(img, group):
    if group == 0:
        img = (img - utils.NAIP_2013_MEANS) / utils.NAIP_2013_STDS
    elif group == 1:
        img = (img - utils.NAIP_2017_MEANS) / utils.NAIP_2017_STDS
    else:
        raise ValueError("group not recognized")
    img = np.rollaxis(img, 2, 0).astype(np.float32)
    img = torch.from_numpy(img)
    return img

def label_transforms(labels, group):
    labels = utils.NLCD_CLASS_TO_IDX_MAP[labels]
    labels = torch.from_numpy(labels)
    return labels

def nodata_check(img, labels):
    return np.any(labels == 0) or np.any(np.sum(img == 0, axis=2) == 4)


def main():
    print("Starting DFC2021 baseline training script at %s" % (str(datetime.datetime.now())))


    #-------------------
    # Setup
    #-------------------
    assert os.path.exists(args.input_fn)

    if os.path.isfile(args.output_dir):
        print("A file was passed as `--output_dir`, please pass a directory!")
        return

    if os.path.exists(args.output_dir) and len(os.listdir(args.output_dir)):
        if args.overwrite:
            print("WARNING! The output directory, %s, already exists, we might overwrite data in it!" % (args.output_dir))
        else:
            print("The output directory, %s, already exists and isn't empty. We don't want to overwrite and existing results, exiting..." % (args.output_dir))
            return
    else:
        print("The output directory doesn't exist or is empty.")
        os.makedirs(args.output_dir, exist_ok=True)

    if torch.cuda.is_available():
        device = torch.device("cuda:%d" % args.gpu)
    else:
        print("WARNING! Torch is reporting that CUDA isn't available, exiting...")
        return

    np.random.seed(args.seed)
    torch.manual_seed(args.seed)


    #-------------------
    # Load input data
    #-------------------
    input_dataframe = pd.read_csv(input_fn)
    image_fns = input_dataframe["image_fn"].values
    label_fns = input_dataframe["label_fn"].values
    groups = input_dataframe["group"].values

    dataset = StreamingGeospatialDataset(
        imagery_fns=image_fns, label_fns=label_fns, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
        image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )

    dataloader = torch.utils.data.DataLoader(
        dataset,
        batch_size=args.batch_size,
        num_workers=NUM_WORKERS,
        pin_memory=True,
    )

    num_training_batches_per_epoch = int(len(image_fns) * NUM_CHIPS_PER_TILE /batch_size)
    print("We will be training with %d batches per epoch" % (num_training_batches_per_epoch))


    #-------------------
    # Setup training
    #-------------------
    if args.model == "unet":
        model = models.get_unet()
    elif args.model == "fcn":
        model = models.get_fcn()
    else:
        raise ValueError("Invalid model")

    model = model.to(device)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, amsgrad=True)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")

    print("Model has %d parameters" % (utils.count_parameters(model)))


    #-------------------
    # Model training
    #-------------------
    training_task_losses = []
    num_times_lr_dropped = 0 
    model_checkpoints = []
    temp_model_fn = os.path.join(args.output_dir, "most_recent_model.pt")

    for epoch in range(args.num_epochs):
        lr = utils.get_lr(optimizer)

        training_losses = utils.fit(
            model,
            device,
            dataloader,
            num_training_batches_per_epoch,
            optimizer,
            criterion,
            epoch,
        )
        scheduler.step(training_losses[0])

        model_checkpoints.append(copy.deepcopy(model.state_dict()))
        if args.save_most_recent:
            torch.save(model.state_dict(), temp_model_fn)

        if utils.get_lr(optimizer) < lr:
            num_times_lr_dropped += 1
            print("")
            print("Learning rate dropped")
            print("")
            
        training_task_losses.append(training_losses[0])
            
        if num_times_lr_dropped == 4:
            break


    #-------------------
    # Save everything
    #-------------------
    save_obj = {
        #'args': args,
        'training_task_losses': training_task_losses,
        "checkpoints": model_checkpoints
    }

    save_obj_fn = "results.pt"
    with open(os.path.join(args.output_dir, save_obj_fn), 'wb') as f:
        torch.save(save_obj, f)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-6be104072412> in <module>()
#      19 import torch.optim as optim
#      20
# ---> 21 import models
#      22 import utils
#      23
#
# ModuleNotFoundError: No module named 'models'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Model

# %%
import functools

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

import segmentation_models_pytorch as smp

import utils

class FCN(nn.Module):

    def __init__(self, num_input_channels, num_output_classes, num_filters=64):
        super(FCN,self).__init__()

        self.conv1 = nn.Conv2d(num_input_channels, num_filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.last =  nn.Conv2d(num_filters, num_output_classes, kernel_size=1, stride=1, padding=0)

    def forward(self,inputs):
        x = F.relu(self.conv1(inputs))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.last(x)
        return x


def get_unet():
    return smp.Unet(
        encoder_name='resnet18', encoder_depth=3, encoder_weights=None,
        decoder_channels=(128, 64, 64), in_channels=4, classes=len(utils.NLCD_CLASSES)
    )

def get_fcn():
    return FCN(num_input_channels=4, num_output_classes=len(utils.NLCD_CLASSES), num_filters=64)
