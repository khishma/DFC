# %% [markdown]
# # One tile

# %% [markdown]
# ## Utils

# %%
# !pip install fiona
# !pip install rasterio
# !pip install tqdm
# Out:
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/37/94/4910fd55246c1d963727b03885ead6ef1cd3748a465f7b0239ab25dfc9a3/Fiona-1.8.18-cp36-cp36m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 341kB/s
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fiona) (2020.12.5)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona) (1.15.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona) (7.1.2)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona) (20.3.0)
# Installing collected packages: click-plugins, munch, cligj, fiona
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 munch-2.5.0
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/33/1a/51baddc8581ead98fcef591624b4b2521b581943a9178912a2ac576e0235/rasterio-1.1.8-1-cp36-cp36m-manylinux1_x86_64.whl (18.3MB)
#      |████████████████████████████████| 18.3MB 254kB/s
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from rasterio) (0.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.19.5)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from rasterio) (7.1.2)
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from rasterio) (20.3.0)
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.3.0 rasterio-1.1.8 snuggs-1.4.7
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
import rasterio 
import matplotlib.pyplot as plt
import numpy as np
import fiona
import pandas as pd
import torch
torch.backends.cudnn.benchmark = True
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import datetime
from tqdm import tqdm
from torchvision.transforms import transforms
import os
import sys
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.errors import RasterioError, RasterioIOError
import torch 
from torchvision import transforms
from torch.utils.data.dataset import IterableDataset

# %%
#Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data for training

# %% [markdown]
# Using NLCD as labels, train with both years at the same time

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)
        
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_both.csv", index=False)

# %% [markdown]
# Using NLCD as labels, train with a single year at a time
#
# 2013 NAIP, 2013 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2013"])
        label_fns.append(properties["nlcd-2013"])
        groups.append(0)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv", index=False)

# %% [markdown]
# 2017 NAIP, 2017 NLCD

# %%
image_fns = []
label_fns = []
groups = []
with fiona.open("/content/drive/MyDrive/Data/DFC_2021/dfc2021_index.geojson") as f:
    for row in f:
        properties = row["properties"]
        image_fns.append(properties["naip-2017"])
        label_fns.append(properties["nlcd-2016"])
        groups.append(1)

df = pd.DataFrame.from_dict({
    "image_fn": image_fns,
    "label_fn": label_fns,
    "group": groups
})

df.to_csv("/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2017.csv", index=False)

# %% [markdown]
# ## Dataset Loader

# %%
#-------------------
# Run on each line in the input
#-------------------
input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'

input_dataframe = pd.read_csv(input_fn,usecols = ['image_fn'], nrows=21 )
#input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
#groups = input_dataframe["group"].values


lst = []
for image_idx in range(len(image_fns)):
  tic = time.time()
  image_fn = image_fns[image_idx]
  group = groups[image_idx]
  lst.append(image_fn)
  print(lst)


  print("(%d/%d) Processing %s" % (image_idx, len(image_fns), image_fn), end=" ... ")
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif']
# (0/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif']
# (1/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif']
# (2/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif']
# (3/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif']
# (4/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif']
# (5/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif']
# (6/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif']
# (7/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif']
# (8/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif']
# (9/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif']
# (10/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif']
# (11/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif']
# (12/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif']
# (13/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif']
# (14/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif']
# (15/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif']
# (16/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif']
# (17/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif']
# (18/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif']
# (19/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif ... ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif', 'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif']
# (20/21) Processing https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif ...

# %%
class StreamingGeospatialDataset(IterableDataset):
    
    def __init__(self, imagery_fns, label_fns=None, groups=None, chip_size=32, num_chips_per_tile=200, windowed_sampling=False, image_transform=None, label_transform=None, nodata_check=None, verbose=False):
        """A torch Dataset for randomly sampling chips from a list of tiles. When used in conjunction with a DataLoader that has `num_workers>1` this Dataset will assign each worker to sample chips from disjoint sets of tiles.
        Args:
            imagery_fns: A list of filenames (or URLS -- anything that `rasterio.open()` can read) pointing to imagery tiles.
            label_fns: A list of filenames of the same size as `imagery_fns` pointing to label mask tiles or `None` if the Dataset should operate in "imagery only mode". Note that we expect `imagery_fns[i]` and `label_fns[i]` to have the same dimension and coordinate system.
            groups: Optional: A list of integers of the same size as `imagery_fns` that gives the "group" membership of each tile. This can be used to normalize imagery from different groups differently.
            chip_size: Desired size of chips (in pixels).
            num_chips_per_tile: Desired number of chips to sample for each tile.
            windowed_sampling: Flag indicating whether we should sample each chip with a read using `rasterio.windows.Window` or whether we should read the whole tile into memory, then sample chips.
            image_transform: A function to apply to each image chip object. If this is `None`, then the only transformation applied to the loaded imagery will be to convert it to a `torch.Tensor`. If this is not `None`, then the function should return a `Torch.tensor`. Further, if `groups` is not `None` then the transform function should expect the imagery as the first argument and the group as the second argument.
            label_transform: Similar to image_transform, but applied to label chips.
            nodata_check: A method that will check an `(image_chip)` or `(image_chip, label_chip)` (if `label_fns` are provided) and return whether or not the chip should be skipped. This can be used, for example, to skip chips that contain nodata values.
            verbose: If `False` we will be quiet.
        """

        if label_fns is None:
            self.fns = imagery_fns
            self.use_labels = False
        else:
            self.fns = list(zip(imagery_fns, label_fns)) 
            self.use_labels = True

        self.groups = groups

        self.chip_size = chip_size
        self.num_chips_per_tile = num_chips_per_tile
        self.windowed_sampling = windowed_sampling

        self.image_transform = image_transform
        self.label_transform = label_transform
        self.nodata_check = nodata_check

        self.verbose = verbose

        if self.verbose:
            print("Constructed StreamingGeospatialDataset")

    def stream_tile_fns(self):
        worker_info = torch.utils.data.get_worker_info()
        if worker_info is None: # In this case we are not loading through a DataLoader with multiple workers
            worker_id = 0
            num_workers = 1
        else:
            worker_id = worker_info.id
            num_workers = worker_info.num_workers

        # We only want to shuffle the order we traverse the files if we are the first worker (else, every worker will shuffle the files...)
        if worker_id == 0:
            np.random.shuffle(self.fns) # in place
        # NOTE: A warning, when different workers are created they will all have the same numpy random seed, however will have different torch random seeds. If you want to use numpy random functions, seed appropriately.
        #seed = torch.randint(low=0,high=2**32-1,size=(1,)).item()
        #np.random.seed(seed) # when different workers spawn, they have the same numpy random seed...

        if self.verbose:
            print("Creating a filename stream for worker %d" % (worker_id))

        # This logic splits up the list of filenames into `num_workers` chunks. Each worker will recieve ceil(num_filenames / num_workers) filenames to generate chips from. If the number of workers doesn't divide the number of filenames evenly then the last worker will have fewer filenames.
        N = len(self.fns)
        num_files_per_worker = int(np.ceil(N / num_workers))
        lower_idx = worker_id * num_files_per_worker
        upper_idx = min(N, (worker_id+1) * num_files_per_worker)
        for idx in range(lower_idx, upper_idx):

            label_fn = None
            if self.use_labels:
                img_fn, label_fn = self.fns[idx]
            else:
                img_fn = self.fns[idx]

            if self.groups is not None:
                group = self.groups[idx]
            else:
                group = None

            if self.verbose:
                print("Worker %d, yielding file %d" % (worker_id, idx))

            yield (img_fn, label_fn, group)

    def stream_chips(self):
        for img_fn, label_fn, group in self.stream_tile_fns():
            num_skipped_chips = 0

            # Open file pointers
            img_fp = rasterio.open(img_fn, "r")
            label_fp = rasterio.open(label_fn, "r") if self.use_labels else None

            height, width = img_fp.shape
            if self.use_labels: # garuntee that our label mask has the same dimensions as our imagery
                t_height, t_width = label_fp.shape
                assert height == t_height and width == t_width


            # If we aren't in windowed sampling mode then we should read the entire tile up front
            img_data = None
            label_data = None
            try:
                if not self.windowed_sampling:
                    img_data = np.rollaxis(img_fp.read(), 0, 3)
                    if self.use_labels:
                        label_data = label_fp.read().squeeze() # assume the label geotiff has a single channel
            except RasterioError as e:
                print("WARNING: Error reading in entire file, skipping to the next file")
                continue

            for i in range(self.num_chips_per_tile):
                # Select the top left pixel of our chip randomly
                x = np.random.randint(0, width-self.chip_size)
                y = np.random.randint(0, height-self.chip_size)

                # Read imagery / labels
                img = None
                labels = None
                if self.windowed_sampling:
                    try:
                        img = np.rollaxis(img_fp.read(window=Window(x, y, self.chip_size, self.chip_size)), 0, 3)
                        print(img.shape)
                        if self.use_labels:
                            labels = label_fp.read(window=Window(x, y, self.chip_size, self.chip_size)).squeeze()
                    except RasterioError:
                        print("WARNING: Error reading chip from file, skipping to the next chip")
                        continue
                else:
                    img = img_data[y:y+self.chip_size, x:x+self.chip_size, :]
                    if self.use_labels:
                        labels = label_data[y:y+self.chip_size, x:x+self.chip_size]

                # Check for no data
                if self.nodata_check is not None:
                    if self.use_labels:
                        skip_chip = self.nodata_check(img, labels)
                    else:
                        skip_chip = self.nodata_check(img)

                    if skip_chip: # The current chip has been identified as invalid by the `nodata_check(...)` method
                        num_skipped_chips += 1
                        continue

                # Transform the imagery
                if self.image_transform is not None:
                    if self.groups is None:
                        img = self.image_transform(img)
                    else:
                        img = self.image_transform(img, group)
                else:
                    img = torch.from_numpy(img).squeeze()

                # Transform the labels
                if self.use_labels:
                    if self.label_transform is not None:
                        if self.groups is None:
                            labels = self.label_transform(labels)
                        else:
                            labels = self.label_transform(labels, group)
                    else:
                        labels = torch.from_numpy(labels).squeeze()


                # Note, that img should be a torch "Double" type (i.e. a np.float32) and labels should be a torch "Long" type (i.e. np.int64)
                if self.use_labels:
                    yield img, labels
                else:
                    yield img

            # Close file pointers
            img_fp.close()
            if self.use_labels:
                label_fp.close()

            if num_skipped_chips>0 and self.verbose:
                print("We skipped %d chips on %s" % (img_fn))

    def __iter__(self):
        if self.verbose:
            print("Creating a new StreamingGeospatialDataset iterator")
        return iter(self.stream_chips())

# %%
input_fn = '/content/drive/MyDrive/Data/DFC_2021/training_set_naip_nlcd_2013.csv'
batch_size = 32

input_dataframe = pd.read_csv(input_fn, nrows=30 )
#input_dataframe = pd.read_csv(input_fn)
image_fns = input_dataframe["image_fn"].values
print(image_fns)
label_fns = input_dataframe["label_fn"].values
print(label_fns)
groups = input_dataframe["group"].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     image_fns, label_fns, test_size=0.33, random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# ['https://dfc2021.blob.core.windows.net/competition-data/naip-2013/546_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/597_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/596_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/595_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/541_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/497_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/496_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/545_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/544_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/543_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/542_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1033_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1032_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1031_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1030_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1083_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1082_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1081_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/979_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/978_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/977_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/976_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1029_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1028_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1027_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1141_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1140_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1139_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1138_naip-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/naip-2013/1191_naip-2013.tif']
# ['https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/546_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/597_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/596_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/595_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/541_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/497_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/496_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/545_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/544_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/543_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/542_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1033_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1032_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1031_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1030_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1083_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1082_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1081_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/979_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/978_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/977_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/976_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1029_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1028_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1027_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1141_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1140_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1139_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1138_nlcd-2013.tif'
#  'https://dfc2021.blob.core.windows.net/competition-data/nlcd-2013/1191_nlcd-2013.tif']
# (20,)
# (10,)

# %% [markdown]
# Hyper-parameters

# %%
NUM_WORKERS = 4
CHIP_SIZE = 32
PADDING = 28
assert PADDING % 2 == 0
HALF_PADDING = PADDING//2
CHIP_STRIDE = CHIP_SIZE - PADDING
batch_size = 32
CHIP_SIZE = 32
NUM_CHIPS_PER_TILE = 100

# %% [markdown]
# Transform Data

# %%
NAIP_2013_MEANS = np.array([117.00, 130.75, 122.50, 159.30])
NAIP_2013_STDS = np.array([38.16, 36.68, 24.30, 66.22])
NAIP_2017_MEANS = np.array([72.84,  86.83, 76.78, 130.82])
NAIP_2017_STDS = np.array([41.78, 34.66, 28.76, 58.95])
NLCD_CLASSES = [ 0, 11, 12, 21, 22, 23, 24, 31, 41, 42, 43, 52, 71, 81, 82, 90, 95] # 16 classes + 1 nodata class ("0"). Note that "12" is "Perennial Ice/Snow" and is not present in Maryland.

NLCD_CLASS_COLORMAP = { # Copied from the emebedded color table in the NLCD data files
    0:  (0, 0, 0, 255),
    11: (70, 107, 159, 255),
    12: (209, 222, 248, 255),
    21: (222, 197, 197, 255),
    22: (217, 146, 130, 255),
    23: (235, 0, 0, 255),
    24: (171, 0, 0, 255),
    31: (179, 172, 159, 255),
    41: (104, 171, 95, 255),
    42: (28, 95, 44, 255),
    43: (181, 197, 143, 255),
    52: (204, 184, 121, 255),
    71: (223, 223, 194, 255),
    81: (220, 217, 57, 255),
    82: (171, 108, 40, 255),
    90: (184, 217, 235, 255),
    95: (108, 159, 184, 255)
}

NLCD_IDX_COLORMAP = {
    idx: NLCD_CLASS_COLORMAP[c]
    for idx, c in enumerate(NLCD_CLASSES)
}

def get_nlcd_class_to_idx_map():
    nlcd_label_to_idx_map = []
    idx = 0
    for i in range(NLCD_CLASSES[-1]+1):
        if i in NLCD_CLASSES:
            nlcd_label_to_idx_map.append(idx)
            idx += 1
        else:
            nlcd_label_to_idx_map.append(0)
    nlcd_label_to_idx_map = np.array(nlcd_label_to_idx_map).astype(np.int64)
    return nlcd_label_to_idx_map

NLCD_CLASS_TO_IDX_MAP = get_nlcd_class_to_idx_map() # I do this computation on import for illustration (this could instead be a length 96 vector that is hardcoded here)


NLCD_IDX_TO_REDUCED_LC_MAP = np.array([
    4,#  0 No data 0
    0,#  1 Open Water
    4,#  2 Ice/Snow
    2,#  3 Developed Open Space
    3,#  4 Developed Low Intensity
    3,#  5 Developed Medium Intensity
    3,#  6 Developed High Intensity
    3,#  7 Barren Land
    1,#  8 Deciduous Forest
    1,#  9 Evergreen Forest
    1,# 10 Mixed Forest
    1,# 11 Shrub/Scrub
    2,# 12 Grassland/Herbaceous
    2,# 13 Pasture/Hay
    2,# 14 Cultivated Crops
    1,# 15 Woody Wetlands
    1,# 16 Emergent Herbaceious Wetlands
])

NLCD_IDX_TO_REDUCED_LC_ACCUMULATOR = np.array([
    [0,0,0,0,1],#  0 No data 0
    [1,0,0,0,0],#  1 Open Water
    [0,0,0,0,1],#  2 Ice/Snow
    [0,0,0,0,0],#  3 Developed Open Space
    [0,0,0,0,0],#  4 Developed Low Intensity
    [0,0,0,1,0],#  5 Developed Medium Intensity
    [0,0,0,1,0],#  6 Developed High Intensity
    [0,0,0,0,0],#  7 Barren Land
    [0,1,0,0,0],#  8 Deciduous Forest
    [0,1,0,0,0],#  9 Evergreen Forest
    [0,1,0,0,0],# 10 Mixed Forest
    [0,1,0,0,0],# 11 Shrub/Scrub
    [0,0,1,0,0],# 12 Grassland/Herbaceous
    [0,0,1,0,0],# 13 Pasture/Hay
    [0,0,1,0,0],# 14 Cultivated Crops
    [0,1,0,0,0],# 15 Woody Wetlands
    [0,1,0,0,0],# 16 Emergent Herbaceious Wetlands
])

def image_transforms(img, group):
    if group == 0:
        img = (img - NAIP_2013_MEANS) / NAIP_2013_STDS
    elif group == 1:
        img = (img - NAIP_2017_MEANS) / NAIP_2017_STDS
    else:
        raise ValueError("group not recognized")
    img = np.rollaxis(img, 2, 0).astype(np.float32)
    img = torch.from_numpy(img)
    return img

def label_transforms(labels, group):
    labels = NLCD_CLASS_TO_IDX_MAP[labels]
    labels = torch.from_numpy(labels)
    return labels

def nodata_check(img, labels):
    return np.any(labels == 0) or np.any(np.sum(img == 0, axis=2) == 4)

# %% [markdown]
# DataLoader

# %%
with rasterio.open(image_fn) as f:
  img = f.read(1)
  input_width, input_height = f.width, f.height
  input_profile = f.profile.copy()
train_dataset = StreamingGeospatialDataset(
        imagery_fns= X_train,label_fns = y_train, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
        image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )
train_dataloader = torch.utils.data.DataLoader(
      train_dataset,batch_size=batch_size,
      num_workers=NUM_WORKERS,
      pin_memory=True,
        )

test_dataset = StreamingGeospatialDataset(
        imagery_fns= X_test, label_fns = y_test, groups=groups, chip_size=CHIP_SIZE, num_chips_per_tile=NUM_CHIPS_PER_TILE, windowed_sampling=False, verbose=False,
        image_transform=image_transforms, label_transform=label_transforms, nodata_check=nodata_check
    )

test_dataloader = torch.utils.data.DataLoader(
      test_dataset,batch_size=batch_size,
      num_workers=NUM_WORKERS,
      pin_memory=True,
        )

# %% [markdown]
# Check the size of the dataset

# %%
dataiter = iter(train_dataloader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 4, 32, 32])
# torch.Size([32, 32, 32])

# %% [markdown]
# Copying the propertieds of the image

# %%
with rasterio.open(image_fn) as f:
  input_width, input_height = f.width, f.height
  input_profile = f.profile.copy()

# %% [markdown]
# ## FCN Model

# %%
import functools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class FCN(nn.Module):

    def __init__(self, num_input_channels, num_output_classes, num_filters=64):
        super(FCN,self).__init__()

        self.conv1 = nn.Conv2d(num_input_channels, num_filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(num_filters, num_filters,        kernel_size=3, stride=1, padding=1)
        self.last =  nn.Conv2d(num_filters, num_output_classes, kernel_size=1, stride=1, padding=0)

    def forward(self,inputs):
        x = F.relu(self.conv1(inputs))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.last(x)
        return x

# %%
model = FCN(num_input_channels=4, num_output_classes=len(NLCD_CLASSES))
print(model)
# Out:
# FCN(
#   (conv1): Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (last): Conv2d(64, 17, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ## Model training

# %%
model = model
optimizer = optim.AdamW(model.parameters(), lr=0.00001, amsgrad=True)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min")
epochs = 30
num_batches= 32

# %%
epoch = epochs
for epoch in range(epoch):
    losses = []
    for batch_idx, (data, targets) in tqdm(enumerate(train_dataloader), total=num_batches, file=sys.stdout):
    
        #optimizer.zero_grad()
        # get the inputs; data is a list of [inputs, labels]

        output = model(data)
        #print(output)
        #print(targets)
        print('the shape of output is',(output.shape))
        print('the shape of x is',data.shape)
        print('the shape of y is',targets.shape)
        #loss = criterion(output, torch.max(y, 1)[1])
        loss = criterion(output,targets)
        losses.append(loss.item())
        # zero the parameter gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        print("Loss at {}th epoch: {}".format(epoch,np.mean(losses)))
# Out:
# Streaming output truncated to the last 5000 lines.
# 35it [00:50,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2091353552209005
# 36it [00:51,  1.34it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.218501927079381
# 37it [00:56,  2.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2290086981497312
# 38it [00:58,  2.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2214855933800721
# 39it [00:58,  1.57s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2141742244362832
# 40it [00:59,  1.24s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2171791108643137
# 41it [00:59,  1.01s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2164792915185292
# 42it [01:00,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2071991022243056
# 43it [01:00,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2070292911746285
# 44it [01:01,  1.51it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2205276515748766
# 45it [01:01,  1.65it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2158313134442205
# 46it [01:02,  1.76it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2121784357314414
# 47it [01:02,  1.76it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2095936288436253
# 48it [01:04,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2100078840644992
# 49it [01:10,  2.37s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2151867794990538
# 50it [01:10,  1.85s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2070022809739207
# 51it [01:11,  1.47s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2000809609889984
# 52it [01:11,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.1962528971006285
# 53it [01:12,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2131159062738772
# 54it [01:12,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2086349129676819
# 55it [01:13,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2066139121140753
# 56it [01:13,  1.58it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2022922300455863
# 57it [01:14,  1.72it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2150213605371014
# 58it [01:14,  1.85it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2120757375733326
# 59it [01:15,  1.93it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 10th epoch: 1.2078989307085672
# 60it [01:15,  1.99it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 10th epoch: 1.2007517677838686
# 61it [01:15,  2.37it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 10th epoch: 1.2115651349867544
# 62it [01:16,  2.58it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 10th epoch: 1.206497521627517
# 63it [01:16,  2.77it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 10th epoch: 1.2057552356272936
# 64it [01:16,  1.20s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.547511100769043
#   3%|▎         | 1/32 [00:15<07:58, 15.43s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.7928615212440491
#   6%|▋         | 2/32 [00:15<05:28, 10.94s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.7186140020688375
#   9%|▉         | 3/32 [00:16<03:46,  7.80s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.8435824364423752
#  12%|█▎        | 4/32 [00:16<02:36,  5.60s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.8440756440162659
#  16%|█▌        | 5/32 [00:17<01:49,  4.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.8908635874589285
#  19%|█▉        | 6/32 [00:17<01:17,  2.98s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.867566066128867
#  22%|██▏       | 7/32 [00:18<00:55,  2.24s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.9306980893015862
#  25%|██▌       | 8/32 [00:18<00:41,  1.72s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.9239844812287225
#  28%|██▊       | 9/32 [00:19<00:35,  1.55s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.91509810090065
#  31%|███▏      | 10/32 [00:20<00:28,  1.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.914158430966464
#  34%|███▍      | 11/32 [00:21<00:22,  1.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.9465620915095011
#  38%|███▊      | 12/32 [00:21<00:19,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.948682033098661
#  41%|████      | 13/32 [00:28<00:48,  2.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.9757075990949359
#  44%|████▍     | 14/32 [00:31<00:52,  2.89s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 0.9925250132878621
#  47%|████▋     | 15/32 [00:32<00:36,  2.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.0002367421984673
#  50%|█████     | 16/32 [00:32<00:26,  1.66s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.0010537540211397
#  53%|█████▎    | 17/32 [00:33<00:19,  1.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.0275158749686346
#  56%|█████▋    | 18/32 [00:33<00:14,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.0248795496790033
#  59%|█████▉    | 19/32 [00:34<00:11,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.050556516647339
#  62%|██████▎   | 20/32 [00:34<00:09,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.044490274928865
#  66%|██████▌   | 21/32 [00:35<00:07,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.0780605565417896
#  69%|██████▉   | 22/32 [00:36<00:08,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.089293106742527
#  72%|███████▏  | 23/32 [00:37<00:07,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.11795541147391
#  75%|███████▌  | 24/32 [00:37<00:05,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.125828924179077
#  78%|███████▊  | 25/32 [00:43<00:16,  2.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1630795918978178
#  81%|████████▏ | 26/32 [00:44<00:11,  1.87s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1611222691006131
#  84%|████████▍ | 27/32 [00:45<00:07,  1.47s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1759062962872642
#  88%|████████▊ | 28/32 [00:45<00:04,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1828743630442127
#  91%|█████████ | 29/32 [00:45<00:02,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1948145747184753
#  94%|█████████▍| 30/32 [00:46<00:01,  1.22it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.2045136074866019
#  97%|█████████▋| 31/32 [00:46<00:00,  1.38it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1862322334200144
# 100%|██████████| 32/32 [00:47<00:00,  1.54it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1830794034582195
# 33it [00:47,  1.67it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.2042734850855434
# 34it [00:48,  1.76it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1929929648126876
# 35it [00:49,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1868093096547656
# 36it [00:50,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1956589399157345
# 37it [00:57,  2.66s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.2058417310840206
# 38it [00:57,  2.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1984687386414943
# 39it [00:58,  1.54s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1912161275744437
# 40it [00:58,  1.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1939571674277143
# 41it [00:59,  1.01it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1932251410824912
# 42it [00:59,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.184067378210467
# 43it [01:00,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1835634803230113
# 44it [01:00,  1.51it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.196976167625851
# 45it [01:01,  1.64it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1923730191977129
# 46it [01:02,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.18899352753416
# 47it [01:03,  1.34it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.186480147143205
# 48it [01:03,  1.41it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1869241680417741
# 49it [01:11,  2.76s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1920046782493592
# 50it [01:11,  2.08s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1838093622058046
# 51it [01:12,  1.60s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1771264122082636
# 52it [01:12,  1.26s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1733132375861115
# 53it [01:13,  1.03s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1900805566045973
# 54it [01:13,  1.16it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1856538967652754
# 55it [01:14,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1838724804776055
# 56it [01:14,  1.52it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1794689778696026
# 57it [01:15,  1.66it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.191680822906823
# 58it [01:15,  1.79it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1885156156653065
# 59it [01:16,  1.88it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 11th epoch: 1.1844691236813862
# 60it [01:16,  1.95it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 11th epoch: 1.1772164487447896
# 61it [01:16,  2.33it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 11th epoch: 1.1878511626874246
# 62it [01:17,  2.59it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 11th epoch: 1.1828705176474557
# 63it [01:17,  2.76it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 11th epoch: 1.1819212725386024
# 64it [01:17,  1.21s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.5239027738571167
#   3%|▎         | 1/32 [00:15<07:48, 15.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.7701680660247803
#   6%|▋         | 2/32 [00:15<05:21, 10.72s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.6963919401168823
#   9%|▉         | 3/32 [00:16<03:41,  7.64s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8249630331993103
#  12%|█▎        | 4/32 [00:16<02:33,  5.49s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8244510293006897
#  16%|█▌        | 5/32 [00:16<01:47,  3.99s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8677031695842743
#  19%|█▉        | 6/32 [00:17<01:16,  2.93s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8448721425873893
#  22%|██▏       | 7/32 [00:17<00:54,  2.20s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9106447771191597
#  25%|██▌       | 8/32 [00:18<00:40,  1.69s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9017936719788445
#  28%|██▊       | 9/32 [00:19<00:35,  1.53s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8914165556430816
#  31%|███▏      | 10/32 [00:20<00:27,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.8895628289742903
#  34%|███▍      | 11/32 [00:20<00:22,  1.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9236936817566553
#  38%|███▊      | 12/32 [00:21<00:18,  1.09it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9255486130714417
#  41%|████      | 13/32 [00:27<00:48,  2.54s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9529014187199729
#  44%|████▍     | 14/32 [00:28<00:35,  1.97s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9702730774879456
#  47%|████▋     | 15/32 [00:28<00:26,  1.55s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9790119715034962
#  50%|█████     | 16/32 [00:29<00:19,  1.23s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 0.9802764969713548
#  53%|█████▎    | 17/32 [00:29<00:15,  1.00s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.00771540734503
#  56%|█████▋    | 18/32 [00:30<00:11,  1.18it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.0052166832120795
#  59%|█████▉    | 19/32 [00:30<00:09,  1.35it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.0308139413595199
#  62%|██████▎   | 20/32 [00:31<00:07,  1.50it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.0249728446915036
#  66%|██████▌   | 21/32 [00:31<00:06,  1.64it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.0588314939628949
#  69%|██████▉   | 22/32 [00:32<00:05,  1.74it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.07069027164708
#  72%|███████▏  | 23/32 [00:33<00:07,  1.28it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.0997258300582569
#  75%|███████▌  | 24/32 [00:34<00:05,  1.34it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1079561066627504
#  78%|███████▊  | 25/32 [00:39<00:15,  2.23s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1441699014260218
#  81%|████████▏ | 26/32 [00:40<00:11,  1.83s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1423021841932226
#  84%|████████▍ | 27/32 [00:41<00:07,  1.50s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.15658771778856
#  88%|████████▊ | 28/32 [00:42<00:04,  1.20s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1636690456291725
#  91%|█████████ | 29/32 [00:42<00:02,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1749559779961904
#  94%|█████████▍| 30/32 [00:43<00:01,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1845785514000924
#  97%|█████████▋| 31/32 [00:43<00:00,  1.36it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1662649065256119
# 100%|██████████| 32/32 [00:44<00:00,  1.52it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1632026108828457
# 33it [00:44,  1.64it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1843152957804062
# 34it [00:45,  1.73it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1733134048325675
# 35it [00:45,  1.81it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1669966048664517
# 36it [00:46,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1753984270869076
# 37it [00:52,  2.11s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1853356392760026
# 38it [00:56,  2.75s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1781364281972249
# 39it [00:56,  2.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1709274664521216
# 40it [00:57,  1.59s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1734939857227047
# 41it [00:57,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1727297547317685
# 42it [00:58,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1637833991716073
# 43it [00:58,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.163069103251804
# 44it [00:59,  1.32it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1765277663866678
# 45it [00:59,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.172022248091905
# 46it [01:00,  1.20it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1688948628750253
# 47it [01:01,  1.27it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1664083438615005
# 48it [01:02,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.166878448457134
# 49it [01:09,  2.63s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1717494094371796
# 50it [01:09,  1.98s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1635333685313953
# 51it [01:10,  1.52s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1570690033527522
# 52it [01:10,  1.20s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1532619640512287
# 53it [01:11,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.169808538975539
# 54it [01:11,  1.21it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.165410701795058
# 55it [01:11,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1638920530676842
# 56it [01:12,  1.56it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1594233983441402
# 57it [01:12,  1.69it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1710695449648232
# 58it [01:13,  1.79it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1676796007964572
# 59it [01:13,  1.88it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 12th epoch: 1.1637330522139868
# 60it [01:14,  1.97it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 12th epoch: 1.1563933657818153
# 61it [01:14,  2.36it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 12th epoch: 1.166745012806308
# 62it [01:14,  2.56it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 12th epoch: 1.1618321982641069
# 63it [01:15,  2.75it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 12th epoch: 1.1606702003628016
# 64it [01:15,  1.18s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.5011239647865295
#   3%|▎         | 1/32 [00:15<08:09, 15.80s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.7486803233623505
#   6%|▋         | 2/32 [00:16<05:36, 11.21s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.6753131945927938
#   9%|▉         | 3/32 [00:16<03:51,  7.99s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8062717318534851
#  12%|█▎        | 4/32 [00:17<02:40,  5.73s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8050914525985717
#  16%|█▌        | 5/32 [00:17<01:52,  4.16s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8452168504397074
#  19%|█▉        | 6/32 [00:18<01:19,  3.06s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8229604618889945
#  22%|██▏       | 7/32 [00:18<00:57,  2.28s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.890961080789566
#  25%|██▌       | 8/32 [00:19<00:41,  1.74s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8802297910054525
#  28%|██▊       | 9/32 [00:19<00:33,  1.46s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8678637623786927
#  31%|███▏      | 10/32 [00:20<00:28,  1.29s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.8651252388954163
#  34%|███▍      | 11/32 [00:21<00:23,  1.12s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.900837317109108
#  38%|███▊      | 12/32 [00:22<00:18,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9027842329098628
#  41%|████      | 13/32 [00:28<00:47,  2.49s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9302579717976707
#  44%|████▍     | 14/32 [00:28<00:34,  1.89s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9480702678362528
#  47%|████▋     | 15/32 [00:29<00:25,  1.47s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9576211608946323
#  50%|█████     | 16/32 [00:31<00:29,  1.82s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9595750149558572
#  53%|█████▎    | 17/32 [00:32<00:21,  1.41s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9877190921041701
#  56%|█████▋    | 18/32 [00:32<00:15,  1.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 0.9856192375484266
#  59%|█████▉    | 19/32 [00:33<00:12,  1.07it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0111339926719665
#  62%|██████▎   | 20/32 [00:33<00:09,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0056855309577215
#  66%|██████▌   | 21/32 [00:34<00:07,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0396662598306483
#  69%|██████▉   | 22/32 [00:34<00:06,  1.57it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0522480607032776
#  72%|███████▏  | 23/32 [00:35<00:05,  1.67it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0816321050127347
#  75%|███████▌  | 24/32 [00:36<00:05,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.0902822947502135
#  78%|███████▊  | 25/32 [00:42<00:15,  2.28s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.12540618960674
#  81%|████████▏ | 26/32 [00:43<00:12,  2.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1237342512166058
#  84%|████████▍ | 27/32 [00:44<00:07,  1.59s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1375046478850501
#  88%|████████▊ | 28/32 [00:44<00:05,  1.25s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1446892002533222
#  91%|█████████ | 29/32 [00:45<00:03,  1.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1552445789178212
#  94%|█████████▍| 30/32 [00:45<00:01,  1.17it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1647889902514796
#  97%|█████████▋| 31/32 [00:46<00:00,  1.34it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1465545371174812
# 100%|██████████| 32/32 [00:46<00:00,  1.49it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1437468962235884
# 33it [00:47,  1.61it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1646755758453817
# 34it [00:47,  1.72it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1540124654769897
# 35it [00:48,  1.30it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.147607809967465
# 36it [00:49,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1555789419122644
# 37it [00:55,  2.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.165301972313931
# 38it [00:57,  2.24s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.15836867919335
# 39it [00:57,  1.71s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.151235231757164
# 40it [00:58,  1.33s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1537510621838454
# 41it [00:58,  1.07s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1530068573497592
# 42it [00:59,  1.12it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.144389245399209
# 43it [00:59,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1435453607277437
# 44it [01:00,  1.45it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1572197318077087
# 45it [01:00,  1.60it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1528220008248868
# 46it [01:01,  1.48it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.149960808297421
# 47it [01:02,  1.53it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.147490577151378
# 48it [01:03,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1480151597334414
# 49it [01:09,  2.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1526889765262605
# 50it [01:10,  1.86s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1444640346601898
# 51it [01:10,  1.45s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1381941070923438
# 52it [01:11,  1.44s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1344242883178424
# 53it [01:12,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1509057967751115
# 54it [01:12,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1465172334150835
# 55it [01:13,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1452744454145432
# 56it [01:13,  1.41it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1407677395301952
# 57it [01:14,  1.58it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1519355034006054
# 58it [01:14,  1.72it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1483913326667528
# 59it [01:15,  1.83it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 13th epoch: 1.1445713937282562
# 60it [01:15,  1.93it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 13th epoch: 1.13719657210053
# 61it [01:15,  2.29it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 13th epoch: 1.1473588905026835
# 62it [01:16,  2.55it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 13th epoch: 1.1424528171145727
# 63it [01:16,  2.74it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 13th epoch: 1.141220474615693
# 64it [01:16,  1.20s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 14th epoch: 0.4842679798603058
#   3%|▎         | 1/32 [00:15<07:49, 15.14s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 14th epoch: 0.7307136207818985
#   6%|▋         | 2/32 [00:15<05:22, 10.74s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# ...
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.0654082877768412
# 54it [01:09,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.0611294372515245
# 55it [01:10,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.0615832672587462
# 56it [01:10,  1.60it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.05666629316514
# 57it [01:11,  1.75it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.064487490674545
# 58it [01:11,  1.85it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.060500419240887
# 59it [01:12,  1.96it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 28th epoch: 1.0571712737282117
# 60it [01:12,  2.04it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 28th epoch: 1.049542409963295
# 61it [01:12,  2.43it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 28th epoch: 1.057964481173023
# 62it [01:13,  2.68it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 28th epoch: 1.0533466504679785
# 63it [01:13,  2.88it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 28th epoch: 1.051647233311087
# 64it [01:13,  1.15s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.40319421887397766
#   3%|▎         | 1/32 [00:19<09:53, 19.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.6723906248807907
#   6%|▋         | 2/32 [00:19<06:46, 13.54s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.5989356438318888
#   9%|▉         | 3/32 [00:20<04:38,  9.61s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7152614891529083
#  12%|█▎        | 4/32 [00:20<03:12,  6.86s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7196930766105651
#  16%|█▌        | 5/32 [00:20<02:13,  4.95s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7554353674252828
#  19%|█▉        | 6/32 [00:21<01:33,  3.60s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7364766342299325
#  22%|██▏       | 7/32 [00:21<01:06,  2.67s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8048510774970055
#  25%|██▌       | 8/32 [00:22<00:48,  2.02s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7857148845990499
#  28%|██▊       | 9/32 [00:23<00:40,  1.76s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7671757459640502
#  31%|███▏      | 10/32 [00:24<00:30,  1.39s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7614534334702925
#  34%|███▍      | 11/32 [00:24<00:24,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7958751022815704
#  38%|███▊      | 12/32 [00:25<00:19,  1.02it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.7998906878324655
#  41%|████      | 13/32 [00:36<01:15,  3.99s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.828783678156989
#  44%|████▍     | 14/32 [00:36<00:52,  2.93s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8498985886573791
#  47%|████▋     | 15/32 [00:37<00:37,  2.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8612627945840359
#  50%|█████     | 16/32 [00:37<00:26,  1.66s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8668944379862618
#  53%|█████▎    | 17/32 [00:38<00:19,  1.30s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8977707790003883
#  56%|█████▋    | 18/32 [00:38<00:14,  1.05s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.8977813093285811
#  59%|█████▉    | 19/32 [00:38<00:11,  1.15it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.9235529005527496
#  62%|██████▎   | 20/32 [00:39<00:09,  1.33it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.9196032115391323
#  66%|██████▌   | 21/32 [00:40<00:09,  1.13it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.9520359093492682
#  69%|██████▉   | 22/32 [00:41<00:08,  1.25it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.9669852878736414
#  72%|███████▏  | 23/32 [00:41<00:06,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 0.9963547090689341
#  75%|███████▌  | 24/32 [00:42<00:05,  1.46it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0066523361206055
#  78%|███████▊  | 25/32 [00:48<00:15,  2.26s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0379595756530762
#  81%|████████▏ | 26/32 [00:49<00:11,  1.87s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0379011145344488
#  84%|████████▍ | 27/32 [00:49<00:07,  1.45s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.052037958587919
#  88%|████████▊ | 28/32 [00:50<00:04,  1.15s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0593565907971612
#  91%|█████████ | 29/32 [00:50<00:02,  1.06it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0666677514712015
#  94%|█████████▍| 30/32 [00:51<00:01,  1.26it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0754826030423563
#  97%|█████████▋| 31/32 [00:51<00:00,  1.42it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0585567727684975
# 100%|██████████| 32/32 [00:52<00:00,  1.56it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.057385448253516
# 33it [00:52,  1.68it/s]                        the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0756738852052128
# 34it [00:53,  1.79it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0664313129016332
# 35it [00:54,  1.29it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0604357636637158
# 36it [00:54,  1.37it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0675237323786761
# 37it [01:00,  2.13s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.076141694658681
# 38it [01:01,  1.83s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0697424503473134
# 39it [01:02,  1.49s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0627453550696373
# 40it [01:02,  1.18s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0658075009904258
# 41it [01:03,  1.04it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0649860770929427
# 42it [01:03,  1.23it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.057194733342459
# 43it [01:04,  1.39it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0555878430604935
# 44it [01:04,  1.55it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0712509751319885
# 45it [01:05,  1.69it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0672432287879612
# 46it [01:05,  1.79it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0655299780216623
# 47it [01:06,  1.76it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0629282568891842
# 48it [01:07,  1.31it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.063404657402817
# 49it [01:13,  2.45s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0662163662910462
# 50it [01:14,  1.89s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0578034847390418
# 51it [01:14,  1.48s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0520541083354216
# 52it [01:15,  1.17s/it]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0479723361303221
# 53it [01:15,  1.05it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0634455139990207
# 54it [01:16,  1.24it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0591826352206144
# 55it [01:16,  1.43it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0596667975187302
# 56it [01:17,  1.59it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0547444809947097
# 57it [01:17,  1.74it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.062479548413178
# 58it [01:17,  1.85it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.0585046743942519
# 59it [01:18,  1.93it/s]the shape of output is torch.Size([32, 17, 32, 32])
# the shape of x is torch.Size([32, 4, 32, 32])
# the shape of y is torch.Size([32, 32, 32])
# Loss at 29th epoch: 1.055176259080569
# 60it [01:18,  2.01it/s]the shape of output is torch.Size([15, 17, 32, 32])
# the shape of x is torch.Size([15, 4, 32, 32])
# the shape of y is torch.Size([15, 32, 32])
# Loss at 29th epoch: 1.0475480536945532
# 61it [01:19,  2.37it/s]the shape of output is torch.Size([19, 17, 32, 32])
# the shape of x is torch.Size([19, 4, 32, 32])
# the shape of y is torch.Size([19, 32, 32])
# Loss at 29th epoch: 1.0559094759725756
# 62it [01:19,  2.62it/s]the shape of output is torch.Size([20, 17, 32, 32])
# the shape of x is torch.Size([20, 4, 32, 32])
# the shape of y is torch.Size([20, 32, 32])
# Loss at 29th epoch: 1.0513091938836234
# 63it [01:19,  2.79it/s]the shape of output is torch.Size([14, 17, 32, 32])
# the shape of x is torch.Size([14, 4, 32, 32])
# the shape of y is torch.Size([14, 32, 32])
# Loss at 29th epoch: 1.0495958337560296
# 64it [01:20,  1.25s/it]

# %% [markdown]
# # Evaluation

# %%
def evaluate(model, device, data_loader, num_batches, criterion, epoch, memo=''):
    model.eval()
    
    losses = []
    tic = time.time()
    for batch_idx, (data, targets) in tqdm(enumerate(data_loader), total=num_batches, file=sys.stdout):
        data = data.to(device)
        targets = targets.to(device)
        
        with torch.no_grad():
            outputs = model(data)
            loss = criterion(outputs, targets)
            losses.append(loss.item())
    
    avg_loss = np.mean(losses)

    print('[{}] Validation Epoch: {}\t Time elapsed: {:.2f} seconds\t Loss: {:.2f}'.format(
        memo, epoch, time.time()-tic, avg_loss), end=""
    )
    print("")
    
    return [avg_loss]

# %%
def score(model, device, data_loader, num_batches):
    model.eval()

    num_classes = model.module.segmentation_head[0].out_channels
    num_samples = len(data_loader.dataset)
    predictions = np.zeros((num_samples, num_classes), dtype=np.float32)
    idx = 0
    for batch_idx, (data, target) in enumerate(data_loader):
        data = data.to(device)
        with torch.no_grad():
            output = F.softmax(model(data))
        batch_size = data.shape[0]
        predictions[idx:idx+batch_size] = output.cpu().numpy()
        idx += batch_size
    return predictions
